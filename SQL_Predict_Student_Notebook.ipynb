# %% [markdown]
# # SQL 4 Data Science: Predict Project
# ## Bhejane Online Trading Store
#
# ### Student Starter Notebook
#
# © Explore Data Science Academy
#
# ### Honour Code
#
# I {**YOUR NAME**, **YOUR SURNAME**}, confirm - by submitting this document - that the solutions in this notebook are a result of my own work and that I abide by the EDSA honour code (https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract.

# %% [markdown]
# <a id='Context'></a>
# ### 1. Context
#
# <div align="center" style="width: 600px; font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Bhejane_large.jpg"
#      alt="The Black Rhino"
#      style="float: center; padding-bottom=0.5em"
#      width=600px/>
#      Bhejane, or the Black Rhino. Image by <a href="https://commons.wikimedia.org/wiki/File:Black_Rhino_(Diceros_bicornis)_browsing_..._(46584052962).jpg">Wikimedia Commons</a>
# </div>
#
#
# The Bhejane trading store is an online retailer specialising in Covid essesstial items. The store has recently be struggling with the management of its database-related inventory system. Luckily for them, you've been hired as a consultant to fix the problem.
#
# Its time to flex your Ninja SQL skills!
#
# **Your mission, should you choose to accept it:**
#
# You will receive a denormalised database consisting of two tables. Your task is to transform the database such that is in third normal form (3NF). To ensure that a consistent normalisation process is followed by each student, we have attached an Entity Relationship Diagram (ERD) which is a guideline on what tables need to be produced. Once you have normalised the databasse, you will be required to complete an MCQ test found under the 'Predict' tab of Athena.

# %% [markdown]
# <a id='Imports'></a>
# ### 2. Imports
# Please use the below command to install sql_magic, this is the package that will assist you with SQL syntax hightlighting.
# * pip install sql_magic
#
# **NB: To run this notebook on Colab, you will also have to install the packages below;**
# * `pip install sqlalchemy==1.4.47`
# * `pip install ipython-sql`
# * `pip install pymysql`
#
# Remember to start each new cell with:  **`%%sql`**

# %%
# DO NOT EDIT THIS CELL
import sqlite3
import csv
from sqlalchemy import create_engine
# %load_ext sql

# Load SQLite database
# %sql sqlite:///bhejane.db

# %% [markdown]
# <a id='Data_description'></a>
# ### 3. Data description
#
# The original database consist of 2 tables.
# * Product Table
# * Transaction Table

# %%
# DO NOT EDIT THIS CELL
import pandas as pd
data_description = pd.read_excel('Data Description.xlsx')
data_description
# Out:
#       Table Name         Column Name  \
# 0       Products               Width
# 1       Products              Length
# 2       Products              Height
# 3       Products             Barcode
# 4       Products            Quantity
# 5       Products               Brand
# 6       Products      NavigationPath
# 7       Products              Colour
# 8       Products        StockCountry
# 9       Products  ProductDescription
# 10      Products            PackType
# 11      Products        Volume_litre
# 12      Products            Warranty
# 13      Products           Weight_kg
# 14      Products     ItemDescription
# 15      Products               Price
# 16  Transactions              CartID
# 17  Transactions             Barcode
# 18  Transactions               Total
# 19  Transactions            UserName
# 20  Transactions         InvoiceDate
#
#                                           Desciption
# 0                 Width of the product once assembled
# 1                Length of the product once assembled
# 2                Height of the product once assembled
# 3                      The unique product identifier
# 4                            Number of goods in stock
# 5      Product brand name relating to product company
# 6                 Navigation path to specific product
# 7                 Name default colour for the product
# 8             Country where the stock was bought from
# 9                            Descriptive product name
# 10           The way in which the product is packaged
# 11              The quantity of liquid based products
# 12                              Product warranty type
# 13                              Weight of the product
# 14            Description of contents of the package
# 15                   The cost of the product in Rands
# 16  Identifies an individual basket from a user pu...
# 17               Barcode for item that user purchased
# 18                      Total value of a transaction
# 19                  Name of customer purchasing stock
# 20               Date on which the product was bought

# %% [markdown]
# <a id='Setting_up'></a>
# ### 4. Setting up the database

# %%
#DO NOT EDIT THIS CELL
conn = sqlite3.connect('bhejane.db')
cursor = conn.cursor()

# %% [markdown]
# #### Creating both Products and Transaction Tables

# %%
# %%sql
# --DO NOT EDIT THIS CELL
# DROP TABLE IF EXISTS "Products";
# DROP TABLE IF EXISTS "Transactions";
#
# CREATE TABLE "Products" (
#     "Width"   REAL,
#     "Length"  REAL,
#     "Height"  REAL,
#     "Barcode" VARCHAR(150) NOT NULL,
#     "Quantity" INTEGER NOT NULL,
#     "Brand" VARCHAR(150),
#     "NavigationPath" VARCHAR(150),
#     "Colour" VARCHAR(150),
#     "StockCountry" VARCHAR(150),
#     "ProductDescription" VARCHAR(150) NOT NULL,
#     "PackType" VARCHAR(150),
#     "Volume_litre" REAL,
#     "Warranty" VARCHAR(150),
#     "Weight_kg" REAL,
#     "ItemDescription" VARCHAR(150),
#     "Price" REAL
# );
#
#
# CREATE TABLE "Transactions" (
#     "CartID" INTEGER,
#     "Barcode" VARCHAR(150),
#     "Total" REAL,
#     "UserName" VARCHAR(150),
#     "InvoiceDate" DATETIME
# );
# Out:
#  * sqlite:///bhejane.db
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# #### Load Data into Product and Transaction tables

# %%
# DO NOT EDIT CELL
# Load data into Product table
with open('bhejane_covid_essentials_Products.csv','r') as fin: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['Width'],i['Length'],i['Height'], i['Barcode'], i['Quantity'], i['Brand'], i['NavigationPath'], i['Colour'], i['StockCountry'], i['ProductDescription'],i['PackType'],i['Volume_litre'],i['Warranty'],i['Weight_kg'],i["ItemDescription"],i['Price']) for i in dr]

cursor.executemany("INSERT INTO Products VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);", to_db)
conn.commit()

with open('bhejane_covid_essentials_Transactions.csv','r') as fin: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['CartID'],i['Barcode'], i['Total'], i['UserName'], i['InvoiceDate']) for i in dr]

cursor.executemany("INSERT INTO Transactions VALUES (?, ?, ?, ?, ?);", to_db)
conn.commit()

# %% [markdown]
# <a id='ERD'></a>
# ### 5. Denormalized Database Tables
#
#
# <br>
#
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/SQL4DS/SQL_Predict/Denormalized_Tables.png" alt="Denormalized Tables" border="0">

# %% [markdown]
# #### 5.1 Explore the Denormalized Tables
# Familiarize yourself with the data given in the two tables by writing your own SQL queries to explore properties of the dataset.i.e Look for data inconsistencies, anormalies, redundancies etc to guide your normalization process.
#
# This section will not be graded - think of it as your own scratch pad.

# %%
# %%sql
# -- #Use this section to explore the database by writing your own queries
# SELECT * FROM Products
# LIMIT 2;
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('', '', '', '300507946', 493, 'Hikvision', 'Computers & Tablets / Smart Home & Connected Living / Home Security / Security Cameras', '', '', 'Hikvision 1080P 2MP Turbo HD IR Bullet Camera', '', 0.0, 'Limited (6 months)', '', '1 x Hikvision 1080P Bullet camera', 399.0),
#  ('', '', '', '300507946', 493, 'Hikvision', 'Computers & Tablets / Smart Home & Connected Living / Home Security / Security Cameras', '', '', 'Hikvision 1080P 2MP Turbo HD IR Bullet Camera', '', 0.0, 'Limited (6 months)', '', 'Manual', 399.0)]

# %% [markdown]
# ### 6. Normalize the given Database tables to the 1st Normal Form (1NF)
#
# Given the below below target ERD create new tables such the the database conforms to the 1st Normal Form
#
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/SQL4DS/SQL_Predict/1NF.png" alt="1st Normal Form ERD" border="0">
#
# It is suggested that you create all your tables before attempting to populate them with data, this will help reduce errors that might creep up due to logical dependencies.

# %% [markdown]
# #### 6.1 Create the tables required for the 1st Normal Form
# Use the above ERD sketch to create the required tables. Please label your tables as they appear in the ERD sketch

# %%
# %%sql
# --#Create tables required for 1NF
# DROP TABLE IF EXISTS "Products_1NF";
# DROP TABLE IF EXISTS "Transactions_1NF";
#
# CREATE TABLE "Products_1NF"(
#     "Barcode" VARCHAR(150) NOT NULL,
#     "NavigationPath" VARCHAR(150) NOT NULL,
#     "ItemDescription" VARCHAR(150) NOT NULL,
#     "ProductDescription" VARCHAR(150) NOT NULL,
#     "Brand" VARCHAR(150),
#     "Price" REAL NOT NULL,
#     "Quantity" INTEGER NOT NULL,
#     "PackType" VARCHAR(150),
#     "Warranty" VARCHAR(150),
#     "StockCountry" VARCHAR(150),
#     "Colour" VARCHAR(150),
#     "Weight_kg" REAL,
#     "Volume_litre" REAL,
#     "Length" REAL,
#     "Width" REAL,
#     "Height" REAL,
#     FOREIGN KEY ("Barcode") REFERENCES "Transactions_1NF" ("Barcode"),
#     PRIMARY KEY("Barcode","NavigationPath","ItemDescription")
# );
#
# CREATE TABLE "Transactions_1NF" (
#     "CartID" INTEGER NOT NULL,
#     "Barcode" VARCHAR(150) NOT NULL,
#     "UserName" VARCHAR(150) NOT NULL,
#     "InvoiceDate" DATETIME NOT NULL,
#     "Total" REAL NOT NULL,
#     FOREIGN KEY ("Barcode") REFERENCES "Products_1NF" ("Barcode"),
#     PRIMARY KEY("CartID", "Barcode")
# );
# Out:
#  * sqlite:///bhejane.db
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# #### 6.2 Populate the tables you have create in the above section.
#
# Populate the tables such that the database conforms to the 1st Normal Form

# %%
# %%sql
# --#Populate the 1NF tables
# DELETE FROM "Products_1NF";
# DELETE FROM "Transactions_1NF";
#
# INSERT INTO "Products_1NF" ("Barcode","NavigationPath","ItemDescription","Colour","ProductDescription","Brand",
#                             "Price","Quantity","PackType","Warranty","StockCountry","Weight_kg",
#                             "Volume_litre","Length","Width","Height")
# SELECT DISTINCT
#      Barcode
#     ,NavigationPath
#     ,ItemDescription
#     ,Colour
#     ,ProductDescription
#     ,Brand
#     ,Price
#     ,Quantity
#     ,PackType
#     ,Warranty
#     ,StockCountry
#     ,Weight_kg
#     ,Volume_litre
#     ,Length
#     ,Width
#     ,Height
# FROM
#     Products;
#
# INSERT INTO "Transactions_1NF"("CartID","Barcode","UserName","InvoiceDate","Total")
# SELECT DISTINCT
#     CartID
#     ,Barcode
#     ,UserName
#     ,InvoiceDate
#     ,Total
# FROM
#     Transactions;
# Out:
#  * sqlite:///bhejane.db
# 0 rows affected.
# 0 rows affected.
# 1162 rows affected.
# 278 rows affected.
# []

# %% [markdown]
# ###  7. Convert the database into its 2nd Normal Form (2NF).
#
# Please label your tables as they appear in the ERD sketch.
#
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/SQL4DS/SQL_Predict/2NF.png" alt="2nd Normal Form ERD" border="0">

# %%
# %%sql
# --#Create tables required for 2NF
#
# DROP TABLE IF EXISTS "Products_2NF";
# DROP TABLE IF EXISTS "Transactions_2NF";
# DROP TABLE IF EXISTS "Navigation_2NF";
# DROP TABLE IF EXISTS "PackageContents_2NF";
# DROP TABLE IF EXISTS "Colours_2NF";
#
#
#
# CREATE TABLE "Products_2NF"(
#     "RegistryID" INTEGER NOT NULL,
#     "Barcode" VARCHAR(150) NOT NULL,
#     "ProductDescription" VARCHAR(150) NOT NULL,
#     "Brand" VARCHAR(150),
#     "Price" REAL NOT NULL,
#     "Quantity" INTEGER NOT NULL,
#     "StockCountry" VARCHAR(150),
#     "Weight_kg" REAL,
#     "Volume_litre" REAL,
#     "Length" REAL,
#     "Width" REAL,
#     "Height" REAL,
#     "PathID" INTEGER,
#     "ItemID" INTEGER,
#     "ColourID" INTEGER,
#     PRIMARY KEY("RegistryID" AUTOINCREMENT),
#     FOREIGN KEY("PathID") REFERENCES "Navigation_2NF" ("PathID"),
#     FOREIGN KEY("ItemID") REFERENCES "PackageContents_2NF" ("ItemID"),
#     FOREIGN KEY("ColourID") REFERENCES "Colours_2NF" ("ColourID")
#     FOREIGN KEY ("Barcode") REFERENCES "Transactions_2NF" ("Barcode")
# );
#
#
#
# CREATE TABLE "Transactions_2NF" (
#     "CartID" INTEGER NOT NULL,
#     "Barcode" VARCHAR(150) NOT NULL,
#     "UserName" VARCHAR(150) NOT NULL,
#     "InvoiceDate" DATETIME NOT NULL,
#     "Total" REAL NOT NULL,
#     FOREIGN KEY ("Barcode") REFERENCES "Products_2NF" ("Barcode"),
#     PRIMARY KEY("CartID", "Barcode")
# );
#
#
# CREATE TABLE "Navigation_2NF"(
#     "PathID" INTEGER NOT NULL,
#     "NavigationPath" VARCHAR(150),
#     PRIMARY KEY("PathID" AUTOINCREMENT)
# );
#
# CREATE TABLE "Colours_2NF"(
#     "ColourID" INTEGER NOT NULL,
#     "Colour" VARCHAR(150),
#     PRIMARY KEY("ColourID" AUTOINCREMENT)
# );
#
# CREATE TABLE "PackageContents_2NF"(
#     "ItemID" INTEGER NOT NULL,
#     "ItemDescription" VARCHAR(150),
#     "PackType" VARCHAR(150),
#     "Warranty" VARCHAR(150),
#     PRIMARY KEY("ItemID" AUTOINCREMENT)
# );
# Out:
#  * sqlite:///bhejane.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
# -- #Populate the tables so that they conform to 2NF
#
# DELETE FROM "Products_2NF";
# DELETE FROM "Transactions_2NF";
# DELETE FROM "Navigation_2NF";
# DELETE FROM "PackageContents_2NF";
# DELETE FROM "Colours_2NF";
#
#
# INSERT INTO "Navigation_2NF"("NavigationPath")
# SELECT DISTINCT
#     NavigationPath
# FROM
#     Products;
#
# INSERT INTO "PackageContents_2NF"("ItemDescription","PackType","Warranty")
# SELECT DISTINCT
#     ItemDescription,
#     PackType,
#     Warranty
# FROM
#     Products
# WHERE ItemDescription <> '';
#
# INSERT INTO "Colours_2NF"("Colour")
# SELECT DISTINCT
#     Colour
# FROM
#     Products
# WHERE Colour <> '';
#
# INSERT INTO "Products_2NF" ("PathID","ItemID","ColourID","Barcode","ProductDescription","Brand","Price",
#                             "Quantity","StockCountry","Weight_kg","Volume_litre",
#                             "Length","Width","Height")
# SELECT
#     Navigation_2NF.PathID,
#     PackageContents_2NF.ItemID,
#     Colours_2NF.ColourID,
#     Barcode,
#     ProductDescription,
#     Brand,
#     Price,
#     Quantity,
#     StockCountry,
#     Weight_kg,
#     Volume_litre,
#     Length,
#     Width,
#     Height
# FROM
#     Products
# LEFT JOIN Navigation_2NF ON Products.NavigationPath = Navigation_2NF.NavigationPath
# LEFT JOIN PackageContents_2NF ON Products.ItemDescription = PackageContents_2NF.ItemDescription
# LEFT JOIN Colours_2NF ON Products.Colour = Colours_2NF.Colour;
#
#
# INSERT INTO "Transactions_2NF"("CartID","Barcode","UserName","InvoiceDate","Total")
# SELECT DISTINCT
#     CartID
#     ,Transactions.Barcode
#     ,UserName
#     ,InvoiceDate
#     ,Total
# FROM
#     Transactions
# JOIN Products_2NF ON Transactions.Barcode = Products_2NF.Barcode ;
# Out:
#  * sqlite:///bhejane.db
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 396 rows affected.
# 600 rows affected.
# 17 rows affected.
# 1214 rows affected.
# 275 rows affected.
# []

# %% [markdown]
# <a id='Target_ERD'></a>
# ### 8. Convert the table into its 3rd Normal Form (3NF)
#
# Please label your tables as they appear in the ERD sketch
#
# <br>
#
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/SQL4DS/SQL_Predict/3NF.png" alt="3rd Normal Form ERD" border="0"></a>

# %%
# %%sql
#
# --#Create tables required for 2NF
# DROP TABLE IF EXISTS "Transactions_3NF";
# DROP TABLE IF EXISTS "Products_3NF";
# DROP TABLE IF EXISTS "Users_3NF";
# DROP TABLE IF EXISTS "Navigation_3NF";
# DROP TABLE IF EXISTS "PackageContents_3NF";
# DROP TABLE IF EXISTS "Colours_3NF";
# DROP TABLE IF EXISTS "Brands_3NF";
# DROP TABLE IF EXISTS "Locations_3NF";
#
# CREATE TABLE "Products_3NF" (
#     "RegistryID" INTEGER NOT NULL,
#     "Barcode" VARCHAR(150) NOT NULL,
#     "ProductDescription" VARCHAR(150) NOT NULL,
#     "Price" REAL NOT NULL,
#     "Quantity" INTEGER NOT NULL,
#     "Weight_kg" REAL,
#     "Volume_litre" REAL,
#     "Length" REAL,
#     "Width" REAL,
#     "Height" REAL,
#     "PathID" INTEGER,
#     "ItemID" INTEGER,
#     "ColourID" INTEGER,
#     "BrandID" INTEGER,
#     "LocationID" INTEGER,
#     PRIMARY KEY("RegistryID" AUTOINCREMENT),
#     FOREIGN KEY("PathID") REFERENCES "Navigation_3NF" ("PathID"),
#     FOREIGN KEY("ItemID") REFERENCES "PackageContents_3NF" ("ItemID"),
#     FOREIGN KEY("ColourID") REFERENCES "Colours_3NF" ("ColourID") ,
#     FOREIGN KEY ("BrandID") REFERENCES "Brands_3NF" ("BrandID"),
#     FOREIGN KEY ("Barcode") REFERENCES "Transactions_3NF" ("Barcode"),
#     FOREIGN KEY ("LocationID") REFERENCES "Locations_3NF" ("LocationID")
# );
#
# CREATE TABLE "Transactions_3NF" (
#     "CartID" INTEGER NOT NULL,
#     "Barcode" VARCHAR(150) NOT NULL,
#     "UserID" VARCHAR(150) NOT NULL,
#     "InvoiceDate" DATETIME NOT NULL,
#     "Total" REAL NOT NULL,
#     FOREIGN KEY ("Barcode") REFERENCES "Products_3NF" ("Barcode"),
#     FOREIGN KEY ("UserID") REFERENCES "Users_3NF"("UserID")
#     PRIMARY KEY("CartID", "Barcode")
# );
#
#
# CREATE TABLE "Users_3NF"(
#     "UserID" INTEGER NOT NULL,
#     UserName VARCHAR(50) NOT NULL,
#     PRIMARY KEY("UserID" AUTOINCREMENT)
# );
#
#
# CREATE TABLE "Navigation_3NF"(
#     "PathID" INTEGER NOT NULL,
#     "NavigationPath" VARCHAR(150),
#     PRIMARY KEY("PathID" AUTOINCREMENT)
# );
#
# CREATE TABLE "PackageContents_3NF"(
#     "ItemID" INTEGER NOT NULL,
#     "ItemDescription" VARCHAR(150),
#     "PackType" VARCHAR(150),
#     "Warranty" VARCHAR(150),
#     PRIMARY KEY("ItemID" AUTOINCREMENT)
# );
#
# CREATE TABLE "Colours_3NF"(
#     "ColourID" INTEGER NOT NULL,
#     "Colour" VARCHAR(150),
#     PRIMARY KEY("ColourID" AUTOINCREMENT)
# );
#
#
# CREATE TABLE "Brands_3NF"(
#     "BrandID" INTEGER NOT NULL,
#     "Brand" VARCHAR(150),
#     PRIMARY KEY("BrandID" AUTOINCREMENT)
# );
#
# CREATE TABLE "Locations_3NF"(
#     "LocationID" INTEGER NOT NULL,
#     "StockCountry" VARCHAR(150),
#     PRIMARY KEY("LocationID" AUTOINCREMENT)
# );
# Out:
#  * sqlite:///bhejane.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
#
# --# Populate the tables to that they conform to the 3rd Normal Form
# DELETE FROM "Products_3NF";
# DELETE FROM "Transactions_3NF";
# DELETE FROM "Users_3NF";
# DELETE FROM "Navigation_3NF";
# DELETE FROM "PackageContents_3NF";
# DELETE FROM "Colours_3NF";
# DELETE FROM "Brands_3NF";
# DELETE FROM "Locations_3NF";
#
# INSERT INTO "Users_3NF" ("UserName")
# SELECT DISTINCT UserName FROM Transactions_2NF;
#
# INSERT INTO "Locations_3NF" ("StockCountry")
# SELECT DISTINCT StockCountry FROM Products_2NF
# WHERE StockCountry <> '';
#
# INSERT INTO "Brands_3NF" ("Brand")
# SELECT DISTINCT Brand FROM Products_2NF
# WHERE Brand <> '';
#
# INSERT INTO "Colours_3NF" ("Colour")
# SELECT DISTINCT Colour FROM Colours_2NF;
#
# INSERT INTO "PackageContents_3NF" ("ItemDescription","PackType","Warranty")
# SELECT DISTINCT
#     ItemDescription,
#     PackType,
#     Warranty
# FROM
#     PackageContents_2NF
# WHERE ItemDescription <> '';
#
# INSERT INTO "Navigation_3NF" ("NavigationPath")
# SELECT DISTINCT
#     NavigationPath
# FROM
#     Navigation_2NF;
#
# INSERT INTO "Transactions_3NF"("CartID","Barcode","UserID","InvoiceDate","Total")
# SELECT DISTINCT
#     CartID
#     ,Transactions_2NF.Barcode
#     ,Users_3NF.UserID
#     ,InvoiceDate
#     ,Total
# FROM
#     Transactions_2NF
# JOIN Products_2NF ON Transactions_2NF.Barcode = Products_2NF.Barcode
# JOIN Users_3NF ON Transactions_2NF.UserName = Users_3NF.Username;
#
#
# INSERT INTO "Products_3NF" ("PathID","ItemID","ColourID","BrandID","LocationID",
#                             "Barcode","ProductDescription","Price",
#                             "Quantity","Weight_kg","Volume_litre",
#                             "Length","Width","Height")
# SELECT
#     Navigation_3NF.PathID,
#     PackageContents_3NF.ItemID,
#     Colours_3NF.ColourID,
#     Brands_3NF.BrandID,
#     Locations_3NF.LocationID,
#     Barcode,
#     ProductDescription,
#     Price,
#     Quantity,
#     Weight_kg,
#     Volume_litre,
#     Length,
#     Width,
#     Height
# FROM
#     Products
# LEFT JOIN Navigation_3NF ON Products.NavigationPath = Navigation_3NF.NavigationPath
# LEFT JOIN PackageContents_3NF ON Products.ItemDescription = PackageContents_3NF.ItemDescription
# LEFT JOIN Colours_3NF ON Products.Colour = Colours_3NF.Colour
# LEFT JOIN Brands_3NF ON Products.Brand = Brands_3NF.Brand
# LEFT JOIN Locations_3NF ON Products.StockCountry = Locations_3NF.StockCountry
# ;
# Out:
#  * sqlite:///bhejane.db
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 158 rows affected.
# 2 rows affected.
# 232 rows affected.
# 17 rows affected.
# 600 rows affected.
# 396 rows affected.
# 275 rows affected.
# 1214 rows affected.
# []

# %% [markdown]
# <a id='MCQ_questions'></a>
# ## 9. MCQ Questions
#
# Having completed the normalisation of the database, you may use the following cells to help you answer the MCQs for the predict.

# %% [markdown]
# Q1) How many products (Total Stock) does the company have?

# %%
# %%sql
# SELECT SUM(Quantity)
# FROM Products_3NF;
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(321931,)]

# %% [markdown]
# Q2) Which user(s) bought from Bhejane on the 25th of March in 2020?

# %%
# %%sql
#
# SELECT UserName
# FROM Users_3NF AS u
# JOIN Transactions_3NF AS t ON t.UserID=u.UserID
# WHERE t.InvoiceDate='2020-03-25 0:00:00';
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('Sandra',)]

# %% [markdown]
# Q3) List the date(s) where Mandla bought something from Bhejane.

# %%
# %%sql
#
# SELECT InvoiceDate
# FROM Transactions_2NF
# WHERE UserName='Mandla';
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('2020-06-07 0:00:00',),
#  ('2020-04-09 0:00:00',),
#  ('2020-04-11 0:00:00',),
#  ('2020-06-07 0:00:00',),
#  ('2020-06-07 0:00:00',)]

# %% [markdown]
# Q4) Which brand has the largest product variety available at Bhejane?

# %%
# %%sql
#
# SELECT COUNT(pc.ItemID),b.Brand
# FROM PackageContents_3NF AS pc
# JOIN Products_3NF AS p ON p.ItemID=pc.ItemID
# JOIN Brands_3NF AS b ON b.BrandID=p.BrandID
# GROUP BY b.Brand
# ORDER BY b.Brand DESC;
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(1, 'rain'),
#  (1, 'orange apple'),
#  (6, 'ezviz'),
#  (3, 'cnt Labs'),
#  (9, 'Xtreem'),
#  (1, 'Windhoek'),
#  (6, 'Western Digital'),
#  (2, 'Weber'),
#  (7, 'WAHL'),
#  (7, 'Volkano'),
#  (1, 'Victoria Gin'),
#  (4, 'Verimark'),
#  (2, 'Varta'),
#  (2, 'VacBag'),
#  (9, 'Unbranded'),
#  (2, 'UGreen'),
#  (3, 'Typek'),
#  (2, 'Tuff-Luv'),
#  (6, 'Treeline'),
#  (1, 'Toshiba'),
#  (1, 'Torch SA'),
#  (1, 'Three Ships'),
#  (1, 'Thermo'),
#  (4, 'Teddy'),
#  (2, 'Tech Geeks'),
#  (16, 'TP-Link'),
#  (6, 'Swingball'),
#  (4, 'Stonebaby'),
#  (3, 'Steel Mate'),
#  (6, 'Starbucks'),
#  (2, 'Sophie Moda'),
#  (1, 'Sony Playstation'),
#  (3, 'Sonoff'),
#  (3, 'Sodastream'),
#  (2, 'Shield Auto'),
#  (1, 'Shield'),
#  (3, 'Seagate'),
#  (2, 'Schwarzkopf'),
#  (35, 'SanDisk'),
#  (2, 'Samyang'),
#  (12, 'Salton'),
#  (1, 'SHOPCOLLAGEN'),
#  (1, 'Ryobi'),
#  (47, 'Russell Hobbs'),
#  (2, 'Romoss'),
#  (1, 'Richelieu'),
#  (1, 'Rhodes'),
#  (1, 'Recharger'),
#  (3, 'Raz Tech'),
#  (1, 'Rawbiotics'),
#  (2, 'RCT'),
#  (2, 'Pyrex'),
#  (2, 'Pure Pleasure'),
#  (3, 'Pure Beginnings'),
#  (6, 'Pritt'),
#  (1, 'Primo Pet'),
#  (12, 'Pilot'),
#  (1, 'Pigeon'),
#  (5, 'Philips'),
#  (4, 'Parrot Products'),
#  (1, 'Parmalat'),
#  (13, 'Pampers'),
#  (1, 'Outback'),
#  (1, 'Oral-B'),
#  (6, 'Optimizor'),
#  (1, 'Old El Paso'),
#  (1, 'OKJA'),
#  (16, 'Nutribullet'),
#  (4, 'Nubian Roc'),
#  (3, 'Neutriherbs'),
#  (2, 'Nestle Nido 1+'),
#  (2, 'Nescafe'),
#  (1, 'NeoVita'),
#  (8, "Nature's Craft"),
#  (1, 'Nano Wave'),
#  (1, 'Nambithi'),
#  (1, 'NAF NAF'),
#  (2, 'Moto-Quip'),
#  (2, 'Motherkind'),
#  (5, 'Montego'),
#  (2, 'Mondi'),
#  (5, 'Mix Box'),
#  (1, 'Milo'),
#  (3, 'Milex'),
#  (2, 'Microsoft'),
#  (2, 'Metalix'),
#  (2, 'Memre'),
#  (11, 'Mellerware'),
#  (2, 'Megamaster'),
#  (4, 'Mecer'),
#  (3, 'Marco'),
#  (3, 'Leisure-Quip'),
#  (6, 'LDNIO'),
#  (3, 'LASA'),
#  (1, 'Klipdrift'),
#  (1, 'Keto Life'),
#  (2, 'Kenwood'),
#  (1, 'KOO'),
#  (1, 'KN95'),
#  (1, 'Johnson & Johnson'),
#  (1, 'Jameson'),
#  (7, 'JBL'),
#  (1, 'J&B'),
#  (3, 'Intelli-Vision Technology'),
#  (2, 'Immunadue'),
#  (8, 'Huawei'),
#  (3, 'House of York'),
#  (1, 'Home Classix'),
#  (2, 'Hikvision'),
#  (2, 'Heineken'),
#  (1, 'Harmonic Health'),
#  (1, 'HTH'),
#  (9, 'HP'),
#  (5, 'Google'),
#  (10, 'GoFreeTech'),
#  (1, 'Glenfiddich'),
#  (11, 'Gizmo'),
#  (15, 'Generic'),
#  (5, 'Finish'),
#  (1, 'Fine Living'),
#  (1, 'Fine Health'),
#  (1, 'Fellowes'),
#  (1, 'Feline Cuisine'),
#  (3, 'FaceMask'),
#  (1, 'Eveready'),
#  (9, 'Energizer'),
#  (7, 'Ematic'),
#  (3, 'Ellies'),
#  (5, 'Duracell'),
#  (2, 'Dinu'),
#  (5, 'Digitronics'),
#  (2, 'Devils Peak'),
#  (3, 'Dettol'),
#  (1, 'Delonghi'),
#  (5, 'Dell'),
#  (1, 'D-Link'),
#  (11, 'Croxley'),
#  (2, 'Consol'),
#  (1, 'Coffee Wholesalers'),
#  (2, 'Catmor'),
#  (1, 'Castle Lite'),
#  (4, 'Castle Free'),
#  (6, 'Casa'),
#  (23, 'Canon'),
#  (3, 'Caffenu'),
#  (8, 'Caffeluxe'),
#  (4, 'Cadac'),
#  (1, 'CORNMI'),
#  (1, 'Buffelsfontein'),
#  (4, 'Bright Star Lighting'),
#  (1, 'Bootlegger'),
#  (1, 'Bombay Sapphire'),
#  (1, 'Boekenhoutskloof'),
#  (1, 'Body Glove'),
#  (1, 'Black African Organics'),
#  (12, 'Berlinger Haus'),
#  (12, 'Bennett Read'),
#  (5, 'Barbie'),
#  (10, 'Baobab'),
#  (2, 'BabyBug'),
#  (7, 'BH Medical'),
#  (1, 'BEARE'),
#  (3, 'Ausdom'),
#  (1, 'Audio City'),
#  (1, 'Athletico'),
#  (3, 'Athleisure by Discovery'),
#  (2, 'Arnotts'),
#  (2, 'Angelcare'),
#  (1, 'Amplify'),
#  (6, 'Alva'),
#  (1, 'All Hands'),
#  (1, 'African Beauty Secret'),
#  (1, 'Addis'),
#  (3, 'Abbott'),
#  (2, 'ADATA'),
#  (1, '&Accessories')]

# %% [markdown]
# Q5) How much did Zanele spend on the 4th of April 2020?

# %%
# %%sql
#
# SELECT DISTINCT(t.Total)
# FROM Transactions_3NF AS t
# JOIN Users_3NF AS u ON u.UserID=t.UserID
# WHERE t.InvoiceDate='2020-04-04 0:00:00'
#     AND u.UserName='Zanele';
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(3464.0,)]

# %% [markdown]
# Q6) Assuming the average pick-up truck can hold 90 $m^{3}$ of stock. How many bags of 'Catmor - Dry Cat Food - Chicken - 4kg' can you fit in the truck? Round down your answer to the nearest whole number.
#
# 1$m^{3}$ = 1000000$cm^{3}$

# %%
# %%sql
#
# SELECT *
# FROM PackageContents_3NF;
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(1, '1 x Hikvision 1080P Bullet camera', '', 'Limited (6 months)'),
#  (2, 'Manual', '', 'Limited (6 months)'),
#  (3, '1 x 350ml Free Air Duster', '', 'Limited (6 months)'),
#  (4, 'Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', '', 'Limited (6 months)'),
#  (5, 'Wahl Easy Cut 15 Piece Complete Hair Clipper Kit', '', 'Limited (6 months)'),
#  (6, '1 x Bombay - Dry Gin - 750ml', 'Single', 'Non-Returnable'),
#  (7, '1x Digitronics Shockproof Clear Case', '', 'Limited (6 months)'),
#  (8, '1 x Digitronics Tempered Glass Screen Protector', '', 'Limited (6 months)'),
#  (9, '1 x Screen Protector Installation Pack', '', 'Limited (6 months)'),
#  (10, '1x Digitronics Tempered Glass Screen Protector', '', 'Limited (6 months)'),
#  (11, '1x Screen Protector Installation Pack', '', 'Limited (6 months)'),
#  (12, '1 x hdmi to VGA Adaptor', '', 'Limited (6 months)'),
#  (13, '1 x Folding Table', '', 'Limited (6 months)'),
#  (14, '1 X SanDisk Cruzer Blade USB Flash Drive 16GB', '', 'Limited (24 months)'),
#  (15, '1 x SDSDQM-016G-B35A', '', 'Limited (60 months)'),
#  (16, '1 x SD Adapter', '', 'Limited (60 months)'),
#  (17, '1 x SDSDQM-032G-B35A', '', 'Limited (60 months)'),
#  (18, '1 x Adapter', '', 'Limited (60 months)'),
#  (19, '1 X USB Cruzer Blade', '', 'Limited (6 months)'),
#  (20, '1 x SDSDUNC-064G-GN6IN', '', 'Limited (120 months)'),
#  (21, '1 x SANDISK CRUZER BLADE 16GB USB2,0 ELECTRIC BLUE FLASH DRIVE', '', 'Limited (60 months)'),
#  (22, '1 x SANDISK CRUZER BLADE 16GB USB2,0 ELECTRIC PINK FLASH DRIVE', '', 'Limited (60 months)'),
#  (23, '1 x SANDISK CRUZER BLADE 16GB USB2,0 ELECTRIC GREEN FLASH DRIVE', '', 'Limited (60 months)'),
#  (24, '1 X USB Ultra Dual', '', 'Limited (6 months)'),
#  (25, 'Memory card', '', 'Limited (120 months)'),
#  (26, '1 x 32GB MicroSDHC SanDisk Ultra Android', '', 'Limited (60 months)'),
#  (27, '30 ml Hyaluronic Acid', '', 'Limited (6 months)'),
#  (28, '1 x 30Q Battery', '', 'Limited (6 months)'),
#  (29, '1 x Laptop stand', '', 'Limited (6 months)'),
#  (30, '4 x Self-adhesive hook and loop pads', '', 'Limited (6 months)'),
#  (31, '2 x Non slip rubber pads', '', 'Limited (6 months)'),
#  (32, '1 x Instruction pamphlet', '', 'Limited (6 months)'),
#  (33, '1 x PS4 controller', '', 'Limited (12 months)'),
#  (34, '1 x WD Blue 1TB Desktop Hard Drive', '', 'Limited (24 months)'),
#  (35, '1 x WD Element 1TB External HDD', '', 'Limited (24 months)'),
#  (36, '1 x USB3,0 Cable', '', 'Limited (24 months)'),
#  (37, '1 x User Guide', '', 'Limited (24 months)'),
#  (38, '1 x WD GREEN 240GB 2,5" SATA3 3D NAND SSD', '', 'Limited (36 months)'),
#  (39, '1 x UPS', '', 'Limited (12 months)'),
#  (40, 'Aersosol Sanitizing spray - single unit 120ml,', '', 'Non-Returnable'),
#  (41, '1x Google Chromecast 3,0 (2018 Model) With HDMI connection attached', '', 'Limited (12 months)'),
#  (42, '1x USB-micro USB Power Cable', '', 'Limited (12 months)'),
#  (43, '1 x 750ml', 'Single', 'Non-Returnable'),
#  (44, 'Charge / Sync Cable', '', 'Limited (6 months)'),
#  (45, '1 x D-Link DWM-222 4G LTE USB Adapter', '', 'Limited (36 months)'),
#  (46, 'Android TV Box', '', 'Limited (12 months)'),
#  (47, 'Bluetooth Remote with Voice Search', '', 'Limited (12 months)'),
#  (48, 'Power adapter', '', 'Limited (12 months)'),
#  (49, 'HDMI cable', '', 'Limited (12 months)'),
#  (50, 'Quick start guide', '', 'Limited (12 months)'),
#  (51, '2 x AAA Batteries', '', 'Limited (12 months)'),
#  (52, '300Mbps Universal Wi-Fi Range Extender TL-WA850RE', '', 'Limited (12 months)'),
#  (53, 'Quick Installation Guide', '', 'Limited (12 months)'),
#  (54, '1 x X-360 Wired Controller Gamepad Compatible with Xbox 360 Game Console and PC', '', 'Limited (6 months)'),
#  (55, '1 x Microsoft Wireless Mobile Mouse 1850', '', 'Limited (36 months)'),
#  (56, '1 x Cartridge', '', 'Limited (6 months)'),
#  (57, '1 x Barbie Colour Reveal doll with surprise look and colour-change face and sculpted hair', '', 'Limited (6 months)'),
#  (58, '1 x Wig', '', 'Limited (6 months)'),
#  (59, '1 x Skirt', '', 'Limited (6 months)'),
#  (60, '1 x Pair of shoes', '', 'Limited (6 months)'),
#  (61, '1 x Sponge', '', 'Limited (6 months)'),
#  (62, '5 x Multi-Pack face masks', '', 'Non-Returnable'),
#  (63, '1 x Cotton facial mask', '', 'Non-Returnable'),
#  (64, 'HP A4 Everyday Paper - White Copy Printer Paper - Box', '', 'Limited (6 months)'),
#  (65, "6 x 72's Gentle All Over Wipes", 'Pack', 'Supplier (18 months)'),
#  (66, '6 x AAA Battery', '', 'Limited (12 months)'),
#  (67, '27 Baby-Dry Nappies', '', 'Non-Returnable (6 months)'),
#  (68, '111 Baby-Dry Nappies', '', 'Non-Returnable (6 months)'),
#  (69, '88 Premium Care Nappies', '', 'Non-Returnable (6 months)'),
#  (70, '224 Sensitive Protect Wipes', '', 'Non-Returnable (6 months)'),
#  (71, '768 Complete Clean Wipes', '', 'Non-Returnable (6 months)'),
#  (72, '336 Sensitive Protect Wipes', '', 'Non-Returnable (6 months)'),
#  (73, '22 Premium Care Nappies', '', 'Non-Returnable (6 months)'),
#  (74, '1 x Rechargeable Toothbrush', '', 'Limited (24 months)'),
#  (75, "1 X Toshiba Canvio Basic 1TB 2,5'' External Hard Drive", '', 'Limited (24 months)'),
#  (76, 'All-In-One printer \\96 Canon PIXMA MG2540S', '', 'Limited (12 months)'),
#  (77, 'FINE Cartridges', '', 'Limited (12 months)'),
#  (78, 'Power cord', '', 'Limited (12 months)'),
#  (79, 'Setup CD-ROM (CD only for Windows \\96 Mac drivers available online)', '', 'Limited (12 months)'),
#  (80, 'Manuals', '', 'Limited (12 months)'),
#  (81, '4-in-one printer - PIXMA TR4540', '', 'Limited (12 months)'),
#  (82, '2 FINE cartridges', '', 'Limited (12 months)'),
#  (83, 'Set-up CD-ROM', '', 'Limited (12 months)'),
#  (84, 'Manuals and other documents', '', 'Limited (12 months)'),
#  (85, 'Adata 20 000 Mah Power Bank - Black , USB - Micro Cable', '', 'Limited (12 months)'),
#  (86, '1 Black Pen', '', 'Limited (6 months)'),
#  (87, '1 Black Pen', '', ''),
#  (88, 'x 60 Breast Pads', '', 'Limited (6 months)'),
#  (89, 'Pack contains 1 Each PG540XL,CL541XL Ink Cartridges', '', 'Non-Returnable (12 months)'),
#  (90, 'Black Ink Cartridge', '', 'Non-Returnable (12 months)'),
#  (91, 'CARTRIDGE', '', 'Limited (6 months)'),
#  (92, '20 x AA', '', 'Limited (24 months)'),
#  (93, '20 x AAA', '', 'Limited (24 months)'),
#  (94, '4 x AA', '', 'Limited (24 months)'),
#  (95, 'AAA Recharge Battery', '', 'Limited (12 months)'),
#  (96, '2 x 2032', '', 'Limited (24 months)'),
#  (97, 'J&B - Rare Scotch Whisky - 750ml', 'Single', 'Non-Returnable'),
#  (98, 'x 1 750ml Glenfiddich - 12 Year Old Special Reserve Single Malt Whisky', 'Single', 'Non-Returnable'),
#  (99, 'x 1 Mixing Bowl 3,0lt', '', 'Limited (6 months)'),
#  (100, 'x 1 750ml Jameson - Irish Whiskey', 'Single', 'Non-Returnable'),
#  (101, 'Finish Auto Dishwashing Machine Cleaner - 250ml', 'Single', 'Non-Returnable (24 months)'),
#  (102, 'Finish Auto Dishwashing Rinse Aid Lemon - 400ml', 'Single', 'Non-Returnable (24 months)'),
#  (103, '1 X Kenwood - Hand Mixer - HM330', '', 'Limited (12 months)'),
#  (104, '1 x Schwarzkopf Got2b Glued Hairspray 300ml', '', 'Non-Returnable (6 months)'),
#  (105, '1x Schwarzkopf Got2b Guardian Angel Heat Protection 200ml', '', 'Non-Returnable'),
#  (106, '1 x Mouse Pad', '', 'Limited (12 months)'),
#  (107, '1 x Ezviz Husky Air Camera', '', 'Limited (24 months)'),
#  (108, '1 x Power Adapter', '', 'Limited (24 months)'),
#  (109, '1 x Mounting Template', '', 'Limited (24 months)'),
#  (110, '1 x Screw Kit', '', 'Limited (24 months)'),
#  (111, '1 x Waterproof Kit', '', 'Limited (24 months)'),
#  (112, '1 x Quick Start Guide', '', 'Limited (24 months)'),
#  (113, '1x Dell LED Monitor', '', 'Supplier (36 months)'),
#  (114, '1x Power Cable', '', 'Supplier (36 months)'),
#  (115, '1x VGA Cable', '', 'Supplier (36 months)'),
#  (116, '1x Stand', '', 'Supplier (36 months)'),
#  (117, '1x Documentation', '', 'Supplier (36 months)'),
#  (118, '1 x 400g', 'Single', 'Non-Returnable'),
#  (119, '50 x Masks In a Box', '', 'Limited (6 months)'),
#  (120, '1 x Face Mask', '', 'Limited (6 months)'),
#  (121, 'x 1 Tin', '', 'Limited (18 months)'),
#  (122, '10 x 12,5g Sachets', '', ''),
#  (123, 'x 1 4kg Bag of Food', '', 'Limited (6 months)'),
#  (124, '1 x Optimizor Premium Chicken', '', 'Limited (6 months)'),
#  (125, 'Rice 20kg', '', 'Limited (6 months)'),
#  (126, '1 x Optimizor Complete Adult Beef 20kg', '', 'Limited (6 months)'),
#  (127, '1 x Catmor - Dry Cat Food - Tuna - 4kg', '', 'Non-Returnable'),
#  (128, '1 X Dettol Original 600ml Shower Gel', '', 'Limited (6 months)'),
#  (129, '6 Dettol Hygiene Kitchen Triggers', '', 'Non-Returnable'),
#  (130, "Finish Auto Dishwashing All in One Tablets Regular - 100's", 'Single', 'Non-Returnable (24 months)'),
#  (131, 'x 1 Rough tote', '', 'Limited (6 months)'),
#  (132, '2x Racquets', '', 'Limited (6 months)'),
#  (133, '1x Ball & Trace', '', 'Limited (6 months)'),
#  (134, '3 Piece interlocking pole', '', 'Limited (6 months)'),
#  (135, 'HTH - Floater+ for Large Pools - 1,6kg', '', 'Limited (6 months)'),
#  (136, 'Markers', '', 'Limited (6 months)'),
#  (137, 'x 1 750ml Three Ships - Select Whisky', '', 'Non-Returnable'),
#  (138, 'x 1 750ml International Brandy', '', 'Non-Returnable'),
#  (139, 'x 1 750ml Klipdrift - Export Brandy', 'Single', 'Non-Returnable'),
#  (140, '1 X Russell Hobbs - 1,7 Litre Cordless Kettle', '', 'Limited (24 months)'),
#  (141, 'x 1 Coffee Grinder', '', 'Limited (12 months)'),
#  (142, 'x 1 Blade', '', 'Limited (12 months)'),
#  (143, 'x 1 12 cup mini muffin pan', '', 'Limited (12 months)'),
#  (144, 'x 1 Salt Grinder', '', 'Limited (24 months)'),
#  (145, 'x 1 Pepper Grinder', '', 'Limited (24 months)'),
#  (146, '18 rolls of 2ply 350 sheets per roll', 'Pack', 'Non-Returnable'),
#  (147, 'x 6 Eveready Power Plus AAA Batteries', '', 'Limited (36 months)'),
#  (148, 'x 1 Metalix Tin Standard Baking Tray', '', 'Limited (12 months)'),
#  (149, '1 x 200 ml Liquid Descaler', '', 'Limited (6 months)'),
#  (150, 'rain 4G SIM', '', 'Non-Returnable'),
#  (151, 'x 24 440ml Windhoek Draught - Beer NRB', 'Case', 'Non-Returnable'),
#  (152, '1 x 220GR Nozzle Valve Gas Cartridge', '', 'Limited (12 months)'),
#  (153, '1 x Cadac Gas Cylinder - 5kg', '', 'Limited (12 months)'),
#  (154, 'x 1 9kg Gas cylinder', '', 'Limited (12 months)'),
#  (155, '1 x cleaning brush', '', 'Limited (6 months)'),
#  (156, '1 x 400ml ice brick', '', 'Limited (6 months)'),
#  (157, '1 x Lamp 1 x USB cable', 'Single', 'Limited (6 months)'),
#  (158, '1 x Rechargeable Lantern', '', 'Supplier (6 months)'),
#  (159, '1 x USB Cable', '', 'Supplier (6 months)'),
#  (160, '1 x Home-Quip USB rechargeable Emergency lantern', 'Single', 'Limited (6 months)'),
#  (161, '1 x USB charging cable', 'Single', 'Limited (6 months)'),
#  (162, 'x 1 Tool Organiser', '', 'Limited (6 months)'),
#  (163, '1 x Shield - MicroFibre All Purpose Cloths 10 Pack', '', 'Limited (6 months)'),
#  (164, 'x 100 Dishwasher Detergent Turbo Tablets', '', 'Non-Returnable (6 months)'),
#  (165, '1x750ml Red Blend', 'Case', 'Non-Returnable'),
#  (166, '6 x 1L Milk', '', 'Limited (6 months)'),
#  (167, 'x 1 Slotted Wooden Spoon', '', 'Limited (12 months)'),
#  (168, 'x 1 Slotted Wooden Spatula', '', 'Limited (12 months)'),
#  (169, '1 x Whiteboard Eraser', '', 'Limited (6 months)'),
#  (170, 'x 1 Classic Manual Microwave', '', 'Limited (24 months)'),
#  (171, 'x 1 Turntable', '', 'Limited (24 months)'),
#  (172, 'x 1 User manual', '', 'Limited (24 months)'),
#  (173, 'x 1 Slow Cooker', '', 'Limited (24 months)'),
#  (174, 'x 1 Ceramic Bowl', '', 'Limited (24 months)'),
#  (175, 'x 1 Lid', '', 'Limited (24 months)'),
#  (176, 'x 1 Recipe Booklet', '', 'Limited (24 months)'),
#  (177, 'x 1 Kettle', '', 'Limited (24 months)'),
#  (178, 'x 1 Base', '', 'Limited (24 months)'),
#  (179, 'x 1 Crumb Tray', '', 'Limited (24 months)'),
#  (180, 'x 1 Toaster', '', 'Limited (24 months)'),
#  (181, 'x 1 Instruction manual', '', 'Limited (24 months)'),
#  (182, 'x 1 Instruction Manual', '', 'Limited (24 months)'),
#  (183, 'x 1 Kettle', '', 'Limited (12 months)'),
#  (184, 'x 1 Base', '', 'Limited (12 months)'),
#  (185, 'x 1 Instruction Manual', '', 'Limited (12 months)'),
#  (186, 'x 1 Sandwich Press', '', 'Limited (24 months)'),
#  (187, '1 x Glass Kitchen Scale - Nero', '', 'Limited (24 months)'),
#  (188, 'x 1 Non-Fitted Electric Blanket', '', 'Limited (12 months)'),
#  (189, 'x 1 Tie Electric Blanket (Size: Single)', '', 'Limited (12 months)'),
#  (190, '1 x Catania 201 2 Tier Dish Drainer', '', 'Limited (12 months)'),
#  (191, '1 x sandwich maker', '', 'Limited (24 months)'),
#  (192, 'x 1 Biltong Maker', '', 'Limited (24 months)'),
#  (193, 'x 4 Panels', '', 'Limited (24 months)'),
#  (194, 'x 2 Drying Shelves', '', 'Limited (24 months)'),
#  (195, 'x 9 Biltong Hooks', '', 'Limited (24 months)'),
#  (196, 'x 3 Hanging Rods', '', 'Limited (24 months)'),
#  (197, 'x 1 Ellies Wonder Surge Adaptor', '', 'Limited (12 months)'),
#  (198, 'x 1 Ellies High Speed HDMI Cable - 1,5m', '', 'Limited (12 months)'),
#  (199, '12 Jumbo Markers', '', 'Limited (6 months)'),
#  (200, '12 Oil Pastels', '', 'Limited (6 months)'),
#  (201, '12 Water Colors', '', 'Limited (6 months)'),
#  (202, '12 Crayons', '', 'Limited (6 months)'),
#  (203, '12 Color Pencils', '', 'Limited (6 months)'),
#  (204, '2 Paper Clips', '', 'Limited (6 months)'),
#  (205, '1 Ruler', '', 'Limited (6 months)'),
#  (206, '1 Sharpener', '', 'Limited (6 months)'),
#  (207, '1 Eraser', '', 'Limited (6 months)'),
#  (208, '1 Paintbrush', '', 'Limited (6 months)'),
#  (209, '1 Storage case', '', 'Limited (6 months)'),
#  (210, 'x 1 Power Base', '', 'Limited (12 months)'),
#  (211, 'x 1 Extractor Blade', '', 'Limited (12 months)'),
#  (212, 'x 1 Tall Cup', '', 'Limited (12 months)'),
#  (213, 'x 1 Short Cup', '', 'Limited (12 months)'),
#  (214, 'x 1 Comfort Lip Ring', '', 'Limited (12 months)'),
#  (215, 'x 1 Stay Fresh Lid', '', 'Limited (12 months)'),
#  (216, 'x 1 User Guide & Recipe Book', '', 'Limited (12 months)'),
#  (217, 'x 1 Pocket Nutritionist', '', 'Limited (12 months)'),
#  (218, '1 x 18 rolls of Toilet Paper', 'Single', 'Limited (6 months)'),
#  (219, 'Castle Lite 24 x 340ml', 'Case', 'Non-Returnable'),
#  (220, 'Castle Free 24 x 340ml', 'Case', 'Non-Returnable'),
#  (221, 'Castle Free 24 x 500ml', 'Case', 'Non-Returnable'),
#  (222, '1 x Gas Level Indicator', '', 'Limited (6 months)'),
#  (223, '1 x 220g canister', '', 'Supplier (12 months)'),
#  (224, '1 x Single canister stove', '', 'Limited (6 months)'),
#  (225, 'Rotatrim A4 White Copy Printer Paper - Box', '', 'Limited (6 months)'),
#  (226, '1 x Mousepad', '', 'Limited (12 months)'),
#  (227, '12 x 400g', 'Case', 'Non-Returnable'),
#  (228, '6 x 352ml jars', 'Pack', 'Limited (6 months)'),
#  (229, '6 x lids', 'Pack', 'Limited (6 months)'),
#  (230, 'Vitamin D3 1000iu - 30 Tablets', '', 'Limited (6 months)'),
#  (231, 'Twista Pull Chopper Base/Bowl', '', 'Lifetime (12 months)'),
#  (232, 'Twista Pull Chopper Lid', '', 'Lifetime (12 months)'),
#  (233, 'Twista Pull Chopper Blades', '', 'Lifetime (12 months)'),
#  (234, 'Twista Pull Chopper Blade Cover', '', 'Lifetime (12 months)'),
#  (235, 'Twista Pull Chopper Recipe Guide and Instruction Manual', '', 'Lifetime (12 months)'),
#  (236, 'Floorwiz 2in1 Mop Head', '', 'Lifetime (12 months)'),
#  (237, 'Floorwiz 2in1 Mop Handle', '', 'Lifetime (12 months)'),
#  (238, 'Header Card Packaging', '', 'Lifetime (12 months)'),
#  (239, '10 x MicroFiber Cloths', 'Single', 'Limited (6 months)'),
#  (240, 'Flawless Unit', '', 'Limited (12 months)'),
#  (241, 'Instruction Manual', '', 'Limited (12 months)'),
#  (242, '1 x AA Battery', '', 'Limited (12 months)'),
#  (243, 'Box Packaging', '', 'Limited (12 months)'),
#  (244, 'x 1 Milex Power Airfryer XXXL', 'Single', 'Limited (12 months)'),
#  (245, 'x 1 Copper-Tech Infused Non-Stick Easy-Load Fry Basket', 'Single', 'Limited (12 months)'),
#  (246, 'x 1 Copper-Tech Infused Food Separator', 'Single', 'Limited (12 months)'),
#  (247, '10 x hangers', '', 'Limited (6 months)'),
#  (248, '50 x pegs', '', 'Limited (6 months)'),
#  (249, '5 x junior hangers', '', 'Limited (6 months)'),
#  (250, '1 x 30cm cover', '', 'Limited (6 months)'),
#  (251, '1 x dustpan scoop', 'Single', 'Limited (6 months)'),
#  (252, '1 x dustpan brush', 'Single', 'Limited (6 months)'),
#  (253, '1 x squeegee', 'Single', 'Limited (6 months)'),
#  (254, '1 x dish brush', 'Single', 'Limited (6 months)'),
#  (255, '1 x pot scrubber', 'Single', 'Limited (6 months)'),
#  (256, 'Typek A4 White Copy Printer Paper - Ream', '', 'Limited (6 months)'),
#  (257, '1 x Typek Box of A4 White Copier Paper', '', 'Limited (6 months)'),
#  (258, 'x 1 LED Floodlight', '', 'Limited (12 months)'),
#  (259, 'x 1 Mounting Bracket', '', 'Limited (12 months)'),
#  (260, "A4 PVC Filing Pockets 100's - 40 Micron", '', 'Limited (6 months)'),
#  (261, '1 x Book', '', 'Limited (6 months)'),
#  (262, '1x Tempered Glass Screenguard', '', 'Limited (6 months)'),
#  (263, '4x410g', 'Pack', 'Non-Returnable'),
#  (264, '6 Way Multiplug with USBs', '', 'Limited (6 months)'),
#  (265, '1 x Pack of 100 Medic Powder-Free Disposable Latex Gloves - Medium', '', 'Limited (6 months)'),
#  (266, '(Pack of 2)iPhone USB Charging Cable for iPhone 5 & 6 &7 & 8 & X - White', '', 'Limited (6 months)'),
#  (267, '2 x 100cm USB Charging Cable For Apple iPhone', '', 'Limited (6 months)'),
#  (268, '1 x Earphones', '', 'Limited (12 months)'),
#  (269, 'Mousepad', '', 'Limited (12 months)'),
#  (270, 'Earphones', '', 'Limited (12 months)'),
#  (271, 'Headphones', '', 'Limited (12 months)'),
#  (272, '2 x Mouse', '', 'Limited (12 months)'),
#  (273, '2 x Box of 200 Tissues', '', 'Non-Returnable (6 months)'),
#  (274, 'x 1 Glue Gun', '', 'Limited (24 months)'),
#  (275, '4 x 100ml tubs', '', 'Limited (6 months)'),
#  (276, '1 x 20 Kg Montego - Monty & Me Essential', '', 'Limited (6 months)'),
#  (277, '1 x 775 g Montego - Classic Dog Wet Food - Adult Chicken', '', 'Limited (6 months)'),
#  (278, '1 x 385 g Montego - Classic Dog Wet Food - Adult Beef', '', 'Limited (6 months)'),
#  (279, '1 x 385 g Montego - Classic Dog Wet Food - Puppy Chicken', '', 'Limited (6 months)'),
#  (280, "1 x 1 Kg Montego - Bags O' Wags Peanut Butter Crunchies box", '', 'Non-Returnable'),
#  (281, 'x 1 750ml Buffelsfontein - Brandy', '', 'Non-Returnable'),
#  (282, '2 x USB Cable Type-A to Apple Lightning', '', 'Limited (6 months)'),
#  (283, '1 x USB Keyboard', '', 'Limited (6 months)'),
#  (284, '1 x USB Mouse', '', 'Limited (6 months)'),
#  (285, '1 x HDMI Cable \\96 1,5M', '', 'Limited (6 months)'),
#  (286, '1 x VR Glasses Unit', '', 'Limited (6 months)'),
#  (287, '1 x Cleaning Cloth', '', 'Limited (6 months)'),
#  (288, 'User Manual', '', 'Limited (6 months)'),
#  (289, '1 X HDMI TO VGA ADAPTOR', '', 'Limited (6 months)'),
#  (290, '25 x African Blend Medium Roast Espresso', 'Single', 'Limited (12 months)'),
#  (291, '25 x French Blend Medium Roast Espresso', 'Single', 'Limited (12 months)'),
#  (292, '25 x Italian Blend Dark Roast Espresso', 'Single', 'Limited (12 months)'),
#  (293, '25 x Brazilian Blend Dark Roast Lungo', 'Single', 'Limited (12 months)'),
#  (294, '1 x 5L 70% Alcohol Hand Sanitizer', '', 'Limited (6 months)'),
#  (295, '1x YM101 Oximeter', '', 'Limited (12 months)'),
#  (296, '1x Lanyard', '', 'Limited (12 months)'),
#  (297, '1x User Manual', '', 'Limited (12 months)'),
#  (298, '1 x Headphones', '', 'Limited (12 months)'),
#  (299, '1 x Scale', 'Single', 'Supplier (12 months)'),
#  (300, '1 x CR2032', 'Single', 'Supplier (12 months)'),
#  (301, '5 x VacBags', '', 'Limited (6 months)'),
#  (302, '1 x Memre - Air Foam Premium Classic Pillow', '', 'Limited (6 months)'),
#  (303, '1 x Memre - Air Foam Contour Pillow', '', 'Limited (6 months)'),
#  (304, '1 x Magneto LED Lantern 2,0 1 User Manual', '', 'Limited (6 months)'),
#  (305, '1 x Main motor unit with power cord and plug', '', 'Limited (12 months)'),
#  (306, '1 x Clear plastic dirt container', '', 'Limited (12 months)'),
#  (307, '1 x Micro Particle Filter', '', 'Limited (12 months)'),
#  (308, '1 x Crevice tool built into dirt container', '', 'Limited (12 months)'),
#  (309, '1 x Floor vacuum nozzle with wheels', '', 'Limited (12 months)'),
#  (310, '1 x Extension tube and handle assembly', '', 'Limited (12 months)'),
#  (311, '1 x User Guide', '', 'Limited (12 months)'),
#  (312, '1 x 5L Bottle', 'Single', 'Non-Returnable'),
#  (313, '1 x 5kg Bucket', 'Single', 'Non-Returnable'),
#  (314, "24 x 330ml Devil's Peak Hero Non-Alc Beers", 'Case', 'Non-Returnable'),
#  (315, '1x face shield', '', 'Non-Returnable'),
#  (316, '1 x Bennett Read Vacuum Sealer 1 x 3m food-grade durable plastic roll', '', 'Limited (6 months)'),
#  (317, '2 x Bennett Read Vacuum Sealer 3m food-grade plastic replacement roll (26,5cm wide)', '', 'Limited (6 months)'),
#  (318, 'Rawbiotics Gut 1 Litre', '', 'Non-Returnable'),
#  (319, '100 Capsules Immunadue', '', 'Limited (6 months)'),
#  (320, '1 x 125ml Baby Bum cream', 'Single', 'Limited (6 months)'),
#  (321, '3 x pack 64 Biodegradable Baby Wipes', 'Single', 'Limited (6 months)'),
#  (322, '1 x 500ml Baby Wash & Shampoo', 'Single', 'Limited (6 months)'),
#  (323, 'x1 Dessert Bowl', '', 'Limited (6 months)'),
#  (324, 'x 1 Folding Table', '', 'Limited (6 months)'),
#  (325, 'x 2 Lighters', '', 'Limited (6 months)'),
#  (326, '1x Yoco Wireless Go Card Machine', '', 'Limited (12 months)'),
#  (327, '1x Charger', '', 'Limited (12 months)'),
#  (328, '1x Yoco Sticker', '', 'Limited (12 months)'),
#  (329, '1 x Bottle of 60 Gummies', '', 'Limited (6 months)'),
#  (330, '1 x Washable N95 Dual Valve Sports Mask - Black', '', 'Non-Returnable'),
#  (331, '1 x Wireless Gateway', '', 'Limited (12 months)'),
#  (332, '1 x Power supply adapter', '', 'Limited (12 months)'),
#  (333, '1 x Quick Start', '', 'Limited (12 months)'),
#  (334, '1 x Ethernet cable', '', 'Limited (12 months)'),
#  (335, '1 x Warranty card', '', 'Limited (12 months)'),
#  (336, 'Huawei E5576', '', 'Limited (12 months)'),
#  (337, 'USB \\96 MicroUSB', '', 'Limited (12 months)'),
#  (338, 'User Guide', '', 'Limited (12 months)'),
#  (339, '1x TLM Colour Changing Foundation', '', 'Non-Returnable'),
#  (340, '1 x Warranty/Warning', '', 'Limited (12 months)'),
#  (341, 'JBL TUNE500 Wired Headphones', '', 'Limited (12 months)'),
#  (342, '1 x JBL TUNE500BT', '', 'Limited (12 months)'),
#  (343, '1 x Charging Cable', '', 'Limited (12 months)'),
#  (344, '1 x QSG/Safety Sheet', '', 'Limited (12 months)'),
#  (345, '1 x RGB Extra Large Gaming Mouse pad', '', 'Limited (6 months)'),
#  (346, '1 x Micro-USB charging cable', '', 'Limited (6 months)'),
#  (347, '1 x User manual', '', 'Limited (6 months)'),
#  (348, 'TP-Link Wireless N Router TL-WR840N', '', 'Limited (24 months)'),
#  (349, 'Power supply unit', '', 'Limited (24 months)'),
#  (350, 'Resource CD', '', 'Limited (24 months)'),
#  (351, 'Ethernet Cable', '', 'Limited (24 months)'),
#  (352, 'Quick Installation Guide', '', 'Limited (24 months)'),
#  (353, 'TP-Link 300Mbps Wireless N 4G LTE Router, TL-MR6400', '', 'Limited (24 months)'),
#  (354, 'RJ45 Ethernet Cable', '', 'Limited (24 months)'),
#  (355, 'Power Adapter', '', 'Limited (24 months)'),
#  (356, 'Micro to Standard SIM Card Adapter', '', 'Limited (24 months)'),
#  (357, 'Nano to Standard SIM Card Adapter', '', 'Limited (24 months)'),
#  (358, '1 x Ausdom AW635 1080P Streaming Web Camera \\96 Black', '', 'Limited (12 months)'),
#  (359, '1 x Mouse', '', 'Limited (12 months)'),
#  (360, 'GoFreeTech GFT-M001 Wireless Optical Mouse - Black', '', 'Limited (12 months)'),
#  (361, 'USB extension cable x 1', '', 'Limited (6 months)'),
#  (362, '1 x Romoss 30 000mah Power Bank', '', 'Limited (12 months)'),
#  (363, 'GFT 104-Key Chiclet Keyboard x1', '', 'Limited (12 months)'),
#  (364, 'GFT Ergonomic 1600DPI Mouse x1', '', 'Limited (12 months)'),
#  (365, 'Nano Receiver x1', '', 'Limited (12 months)'),
#  (366, 'AA Battery for Mouse x1', '', 'Limited (12 months)'),
#  (367, 'AAA Batteries for Keyboard x2', '', 'Limited (12 months)'),
#  (368, 'User Manual x1', '', 'Limited (12 months)'),
#  (369, '1 x Digital Infrared Thermometer', '', 'Limited (6 months)'),
#  (370, '1 x 60L Cylinder', '', 'Limited (6 months)'),
#  (371, 'x 2 Classic Carbonating Bottles', '', 'Limited (6 months)'),
#  (372, '12 Pods', 'Single', 'Non-Returnable'),
#  (373, '10 Capsules', 'Single', 'Non-Returnable'),
#  (374, 'Expansion Portable hard drive', '', 'Limited (12 months)'),
#  (375, 'USB 3,0 cable', '', 'Limited (12 months)'),
#  (376, '504 Sensitive Protect Wipes', '', 'Non-Returnable (6 months)'),
#  (377, '100 Pampers Pants', 'Single', 'Non-Returnable (6 months)'),
#  (378, '96 Pampers Pants', 'Single', 'Non-Returnable (6 months)'),
#  (379, '2 x Latte Glasses', '', 'Limited (12 months)'),
#  (380, '1 x 43g glue sticks', '', 'Limited (6 months)'),
#  (381, '1 x 165g', 'Single', 'Non-Returnable'),
#  (382, 'x 1 Abbott - Similac Total Comfort 1 820g', 'Single', 'Non-Returnable'),
#  (383, 'x 1 Abbott - Similac Total Comfort 3 820g', 'Single', 'Non-Returnable'),
#  (384, '1 X Philips - Steam Iron - Green', '', 'Limited (24 months)'),
#  (385, 'x 1 Descaling Cycle Machine Descaler', '', 'Limited (24 months)'),
#  (386, 'x 1 Pediasure Complete Vanilla - 850g', 'Single', 'Non-Returnable'),
#  (387, '24 x 330ML NRB', 'Case', 'Non-Returnable'),
#  (388, '1 x Cartridge', '', 'Non-Returnable'),
#  (389, '10 x 15 cm PP-201 5 Sheets', '', 'Limited (6 months)'),
#  (390, '10 x 15cm SG-201 5 sheets', '', 'Limited (6 months)'),
#  (391, 'A4 MP-101 5 Sheets', '', 'Limited (6 months)'),
#  (392, 'A4 GP-501 5 sheets', '', 'Limited (6 months)'),
#  (393, 'Energizer CR2032 3v Lithium Coin Battery Card 2', '', 'Limited (12 months)'),
#  (394, '1 X Energizer Miniature Aaaa: E96 (2 Pack) (Moq 12)', '', 'Limited (6 months)'),
#  (395, '1 X Energizer Recharge 2300Mah Aa - 4 Pack (Moq6)', '', 'Limited (6 months)'),
#  (396, '1 X Energizer Recharge 700Mah Aaa - 4 Pack (Moq6)', '', 'Limited (6 months)'),
#  (397, '1 x 200g Chocolate Biscuits', 'Single', 'Non-Returnable'),
#  (398, '1 x 200g Double Coat Chocolate Biscuits', 'Single', 'Non-Returnable'),
#  (399, '1 x Pain Relief Roll-On - 50ml', '', 'Limited (6 months)'),
#  (400, '4 x Books', '', 'Limited (6 months)'),
#  (401, 'x 3 4kg Briquettes', '', 'Limited (6 months)'),
#  (402, '1 x Infrared Thermometer', '', 'Limited (6 months)'),
#  (403, '1 x Pack of 20 KN95 Mask', '', 'Limited (6 months)'),
#  (404, '2 x Face Mask - Reusable Sponge with 1 Breathing Valve', '', 'Limited (6 months)'),
#  (405, '1 x Ink Cartridge', '', 'Non-Returnable'),
#  (406, '1 x Sponge Mask with 1 valve', '', 'Limited (6 months)'),
#  (407, '1 x Reusable Filter Vent Face Mask', '', 'Limited (6 months)'),
#  (408, '1 x pocket size stun gun tazer', '', 'Limited (6 months)'),
#  (409, '1x charger', '', 'Limited (6 months)'),
#  (410, '1 x Sponge Mask with 2 valves', '', 'Limited (6 months)'),
#  (411, '1 - PPE Face Shield - Direct Splash Protection', '', 'Limited (6 months)'),
#  (412, '1 x Dock/ Stand', '', 'Limited (6 months)'),
#  (413, 'Coffee Beans', '', 'Limited (6 months)'),
#  (414, '1 Sponge Mask', '', 'Non-Returnable'),
#  (415, '1x LED SMD Ring Fill Light', '', 'Limited (6 months)'),
#  (416, '1x Cellphone Holder', '', 'Limited (6 months)'),
#  (417, '1x USB Plug', '', 'Limited (6 months)'),
#  (418, '1x Tripod', '', 'Limited (6 months)'),
#  (419, '1 x MS212 soundbar speaker', '', 'Limited (6 months)'),
#  (420, '1 x 3,5mm stereo jack to RCA cable', '', 'Limited (6 months)'),
#  (421, '1 x Mask', '', 'Limited (6 months)'),
#  (422, '5 x Coloured Resistance Bands', '', 'Limited (6 months)'),
#  (423, '1 x Carrying Pouch', '', 'Limited (6 months)'),
#  (424, '20 x Disposable KN95 Face Mask', '', 'Limited (6 months)'),
#  (425, '1 x Face Mask (includes 2 free filters equipped onto mask)', '', 'Limited (6 months)'),
#  (426, '1x UPS Unit', '', 'Limited (24 months)'),
#  (427, '2x MALE TO FEMALE EXTENSION POWER CORD IEC C13-C14 (From UPS to PC)', '', 'Limited (24 months)'),
#  (428, '1x USB Cable (From UPS to PC)', '', 'Limited (24 months)'),
#  (429, '1x Driver Disk', '', 'Limited (24 months)'),
#  (430, '10m Extension Cord With A Two-Way Multi-Plug Extension Lead', '', 'Limited (6 months)'),
#  (431, 'Prepaid Electricity Meter 80Amp, Seal, Registration form and meter card', '', 'Limited (6 months)'),
#  (432, '1x 16cm saucepan', '', 'Limited (6 months)'),
#  (433, '1x 16cm casserole', '', 'Limited (6 months)'),
#  (434, '1x 18cm casserole', '', 'Limited (6 months)'),
#  (435, '1x20cm casserole', '', 'Limited (6 months)'),
#  (436, '1x 24 cm casserole', '', 'Limited (6 months)'),
#  (437, '1x 24 cm frypan', '', 'Limited (6 months)'),
#  (438, '2x 16cm lid', '', 'Limited (6 months)'),
#  (439, '1x 18cm lid', '', 'Limited (6 months)'),
#  (440, '1x 20cm lid', '', 'Limited (6 months)'),
#  (441, '2x 24 cm lid', '', 'Limited (6 months)'),
#  (442, '3x spoons', '', 'Limited (6 months)'),
#  (443, '1x7 Ports USB 2,0 HUB - High Speed USB HUB - Black', '', 'Limited (6 months)'),
#  (444, '1 x 4-Tier Storage Rack', '', 'Limited (6 months)'),
#  (445, 'Aluminium Fold Away Wash Line', '', 'Limited (12 months)'),
#  (446, '1 x Keyboard & Mouse', '', 'Limited (6 months)'),
#  (447, '3 Way Adaptor With Usb Charger', '', 'Limited (12 months)'),
#  (448, '1 x Retinol Serum', '', 'Limited (6 months)'),
#  (449, '1 x Vitamin C Serum', '', 'Limited (6 months)'),
#  (450, '1 x Hyaluronic Serum', '', 'Limited (6 months)'),
#  (451, '1 x Compatible Canon 737 Black Laser Toner Cartridge', '', 'Limited (6 months)'),
#  (452, '1 X LDNIO Micro USB Charge Cable for Android Phones - Dual Pack', '', 'Limited (6 months)'),
#  (453, '1 x Replica iPhone Headset', '', 'Limited (6 months)'),
#  (454, '1 x Earbud Earphones H5 - White', '', 'Limited (6 months)'),
#  (455, '1 x Night Light', '', 'Limited (6 months)'),
#  (456, 'STAR MASTER', '', 'Limited (6 months)'),
#  (457, '1 x mousepad', '', 'Limited (6 months)'),
#  (458, '1x cooking thermometer', '', 'Limited (6 months)'),
#  (459, 'LED Flashlight, 1 Home Charger, 1 Lithium Battery', '', 'Limited (6 months)'),
#  (460, '1X 5M BRAIDED CABLE', '', 'Limited (6 months)'),
#  (461, '1X 10M BRAIDED HDMI CABLE', '', 'Limited (6 months)'),
#  (462, '1 x USB-C to USB-A cable', '', 'Limited (6 months)'),
#  (463, '1 x Waist Training Belt', '', 'Limited (6 months)'),
#  (464, '1 x Camera', '', 'Limited (6 months)'),
#  (465, '1 x Sports Face Mask', '', 'Limited (6 months)'),
#  (466, '1 x Pre-installed filter', '', 'Limited (6 months)'),
#  (467, '1 x Sponge mask with panda valve', '', 'Limited (6 months)'),
#  (468, '1x PS3 Wireless Double Stock Controller', '', 'Limited (6 months)'),
#  (469, '1 x Chef knife 20 cm', '', 'Limited (6 months)'),
#  (470, '1 x Bread knife 20 cm', '', 'Limited (6 months)'),
#  (471, '1 x Santoku knife 17,5 cm', '', 'Limited (6 months)'),
#  (472, '1 x Utility knife 12,5 cm', '', 'Limited (6 months)'),
#  (473, '1 x Paring knife 9 cm', '', 'Limited (6 months)'),
#  (474, '1 x Santoku knife 9 cm', '', 'Limited (6 months)'),
#  (475, '1 x Jack Adapter', '', 'Limited (6 months)'),
#  (476, '1 sleeve containing 10 individual capsules filled with Bootlegger 100% Arabica coffee', '', 'Limited (6 months)'),
#  (477, '1x 10 Amp Wifi Switch', '', 'Limited (6 months)'),
#  (478, '4x Screws', '', 'Limited (6 months)'),
#  (479, '1x Manual', '', 'Limited (6 months)'),
#  (480, '1 x Charging Station PS4 Playstation Dual Shock Controller', '', 'Limited (6 months)'),
#  (481, '1X 3M HDMI CABLE', '', 'Limited (6 months)'),
#  (482, 'Lasa 500g/0,01g Digital Pocket Scale', '', 'Limited (6 months)'),
#  (483, '1 x Wireless Wifi Extender Repeater (US Plug)', '', 'Limited (6 months)'),
#  (484, '1 x RJ-45 Networking Cable', '', 'Limited (6 months)'),
#  (485, ' x Installation Manual', '', 'Limited (6 months)'),
#  (486, '1 x Installation Manual', '', 'Limited (6 months)'),
#  (487, '1 x Micro USB Cable', '', 'Limited (6 months)'),
#  (488, '1x dual wall charger', '', 'Limited (6 months)'),
#  (489, 'Charging Cable for Iphone 6 /7 /7 Plus/8 & 8 Plus', '', 'Limited (6 months)'),
#  (490, 'Digital Temperature & Humidity Thermometer Indoor Clock', '', 'Limited (6 months)'),
#  (491, '5 x resistance bands', '', 'Limited (6 months)'),
#  (492, '1 x carry case', '', 'Limited (6 months)'),
#  (493, '1 x Therapy Heater Bag', '', 'Limited (6 months)'),
#  (494, '1 x Instruction Card', '', 'Limited (6 months)'),
#  (495, 'Google Home Mini', '', 'Limited (12 months)'),
#  (496, 'Power adapter and cable', '', 'Limited (12 months)'),
#  (497, '1 x Transparent Clear Shockproof Case for iPhone 6 and 6s (4,7 inch)', '', 'Limited (6 months)'),
#  (498, '1 x Peptiplus Pure Granulated Collagen Hydroslysate - 200g', '', 'Limited (6 months)'),
#  (499, '1 x Screen Protector', '', 'Limited (6 months)'),
#  (500, '1 x Wet Wipe', '', 'Limited (6 months)'),
#  (501, '1 x Dust Absorber', '', 'Limited (6 months)'),
#  (502, 'Wireless Bluetooth Receiver 3,5mm Jack Audio Music Adapter', '', 'Limited (6 months)'),
#  (503, '1 x Game Controller', '', 'Limited (6 months)'),
#  (504, '1 x User Manuel', '', 'Limited (6 months)'),
#  (505, 'Watch Strap', '', 'Limited (6 months)'),
#  (506, 'Pair of -i7S TWS Bluetooth Earbuds', '', 'Limited (6 months)'),
#  (507, '1x Charging Cable', '', 'Limited (6 months)'),
#  (508, '1x Beard Oil', '', 'Limited (6 months)'),
#  (509, '1 x Bluetooth Earphone Set', '', 'Limited (6 months)'),
#  (510, '1 x Charging Box', '', 'Limited (6 months)'),
#  (511, '1 x Charging Cable', '', 'Limited (6 months)'),
#  (512, '1 x Tempered glass', '', 'Limited (6 months)'),
#  (513, '1x Torch', '', 'Limited (6 months)'),
#  (514, '1x USB Connector', '', 'Limited (6 months)'),
#  (515, '1x 100cm White Sync & Charging Cable', '', 'Limited (6 months)'),
#  (516, '1 x 5 Meter LED RGB Strip Light', '', 'Limited (12 months)'),
#  (517, '1 x 24 key IR remote controller', '', 'Limited (12 months)'),
#  (518, '1 x IR Controller', '', 'Limited (12 months)'),
#  (519, '1 x 12V 3A Power Supply', '', 'Limited (12 months)'),
#  (520, '1 x Skipping Rope', '', 'Limited (6 months)'),
#  (521, '1x 15Kg Cat Litter', '', 'Non-Returnable'),
#  (522, '250grams Unrefind Shea butter', '', 'Non-Returnable'),
#  (523, '200grams African Black Soap', '', 'Limited (6 months)'),
#  (524, '100ml Bottle', '', 'Lifetime (6 months)'),
#  (525, '1 x 5M LED strip light', '', 'Limited (6 months)'),
#  (526, '1 x Power supply', '', 'Limited (6 months)'),
#  (527, '1 x RGB control box', '', 'Limited (6 months)'),
#  (528, '1 x remote control', '', 'Limited (6 months)'),
#  (529, '1 x user manual', '', 'Limited (6 months)'),
#  (530, '1 x Bluetooth Speaker', '', 'Limited (6 months)'),
#  (531, '1 x USB cable', '', 'Limited (6 months)'),
#  (532, '5 x individually packed single noodle (130g)', 'Pack', 'Limited (6 months)'),
#  (533, '1 self-timer with 360\\B0 rotating ball head', '', 'Limited (6 months)'),
#  (534, '1 mobile phone tripod mounting bracket', '', 'Limited (6 months)'),
#  (535, '1 remote control', '', 'Limited (6 months)'),
#  (536, '1 mobile phone holder', '', 'Limited (6 months)'),
#  (537, '1 x USB Humidifier', '', 'Limited (6 months)'),
#  (538, '2 x Standard Pillows', '', 'Limited (6 months)'),
#  (539, '30 Tablets', '', 'Limited (6 months)'),
#  (540, '1 x Ring Light', '', 'Limited (6 months)'),
#  (541, '1 x Tripod Stand', '', 'Limited (6 months)'),
#  (542, '1 x Selfie Ring light with stand', '', 'Limited (6 months)'),
#  (543, '1 x LED SMD Ring Fill Light', '', 'Limited (6 months)'),
#  (544, '1 x Cellphone Holder', '', 'Limited (6 months)'),
#  (545, '1 x USB Plug', '', 'Limited (6 months)'),
#  (546, '1 x Tripod', '', 'Limited (6 months)'),
#  (547, 'Pure Hydrolyzed Collagen', '', 'Limited (6 months)'),
#  (548, '30 x Capsules and Leaflet inside bottle', '', 'Limited (6 months)'),
#  (549, '12 x 1 litre', '', 'Limited (6 months)'),
#  (550, '1 x 10 Capsules Mpesu', '', 'Limited (6 months)'),
#  (551, '10 x Makeup Brush', '', 'Limited (6 months)'),
#  (552, 'Each Box Contains: 50 x DMM-NS', '', 'Limited (6 months)'),
#  (553, '4 x Printed Masks', '', 'Limited (6 months)'),
#  (554, '4 x Printed Face Masks', '', 'Limited (6 months)'),
#  (555, '1 x Sport Face Mask', '', 'Non-Returnable'),
#  (556, '1 x Pre-installed filter', '', 'Non-Returnable'),
#  (557, '2 x Extra Replacement Filters', '', 'Non-Returnable'),
#  (558, '5 X Anti-fog Transparent Plastic Full Face Shield', '', 'Full (6 months)'),
#  (559, '20 x 3 Ply Surgical Masks', '', 'Limited (6 months)'),
#  (560, '1x Visor', '', 'Limited (6 months)'),
#  (561, '1x Headband', '', 'Limited (6 months)'),
#  (562, '50 x Face Masks', '', 'Limited (6 months)'),
#  (563, '1 x Keyboard', '', 'Limited (6 months)'),
#  (564, '1 x Manual', '', 'Limited (6 months)'),
#  (565, '50 x Individual 3ply Blue Face Masks', '', 'Limited (6 months)'),
#  (566, '1 x KetoVatru', '', 'Limited (6 months)'),
#  (567, '3 x Masks', '', 'Limited (6 months)'),
#  (568, '1 x Reusable Kids Face Mask', '', 'Limited (6 months)'),
#  (569, '50 x Masks', '', 'Full (6 months)'),
#  (570, '1x N95 FFP2 Medical Protective Mask', '', 'Limited (6 months)'),
#  (571, '1 x Black Durag', '', 'Limited (6 months)'),
#  (572, '4 x Reusable Kids Face Mask', '', 'Limited (6 months)'),
#  (573, '4 x Reusable Face Masks', '', 'Limited (6 months)'),
#  (574, '1 x Black Nano Wave Mask Adult', '', 'Limited (6 months)'),
#  (575, "1 x Children's Face Mask", '', 'Limited (6 months)'),
#  (576, '1 x Reusable Face Mask with Vent', '', 'Limited (6 months)'),
#  (577, '1 x Sponge Mask', '', 'Non-Returnable'),
#  (578, '1 x Finger Pulse Oximeter', '', 'Limited (6 months)'),
#  (579, '1 x Lanyard', '', 'Limited (6 months)'),
#  (580, '2 x AAA Batteries', '', 'Limited (6 months)'),
#  (581, '3 x Reusable Face Mask with Vent', '', 'Limited (6 months)'),
#  (582, '3 x Reusable Filter Vent Face Mask', '', 'Limited (6 months)'),
#  (583, '5 x Face masks', '', 'Limited (6 months)'),
#  (584, '1 x Sponge Mask', '', 'Limited (6 months)'),
#  (585, '1 x Instruction Manual', '', 'Limited (6 months)'),
#  (586, '3 x Vitamin C + Selenium & Zinc Immune Booster', '', 'Limited (6 months)'),
#  (587, '1 x Sponge Mask with 1 Valve', '', 'Limited (6 months)'),
#  (588, '1 x Travel adapter (EU plug)', '', 'Limited (6 months)'),
#  (589, 'Samsung And Other Smartphone Charger (Micro USB Cable And Wall Adapter)', '', 'Limited (6 months)'),
#  (590, '1 X 10ml Pure Essential Oil Bottle', '', 'Limited (6 months)'),
#  (591, '8 x 10ml Pure Essential Oil Bottle', '', 'Limited (6 months)'),
#  (592, '1 x Lavender', '', 'Limited (6 months)'),
#  (593, '1 x Lemongrass', '', 'Limited (6 months)'),
#  (594, '1 x Tea Tree', '', 'Limited (6 months)'),
#  (595, '1 x Sweet Orange', '', 'Limited (6 months)'),
#  (596, '1 x Rosemary', '', 'Limited (6 months)'),
#  (597, '1 x Peppermint', '', 'Limited (6 months)'),
#  (598, '1 x Oximiter and Manual', '', 'Limited (6 months)'),
#  (599, 'x 3 Nappy Bin Refills', '', 'Limited (6 months)'),
#  (600, '384 Complete Clean Wipes', '', 'Non-Returnable (6 months)')]

# %% [markdown]
# Q7) Which user spent the most having only bought 4 items in the Year 2020?

# %%
# %%sql
#
# SELECT COUNT(t.Total) ,u.UserName,t.Total
# FROM Transactions_3NF AS t
# JOIN Users_3NF AS u ON u.UserID=t.UserID
# WHERE t.InvoiceDate LIKE '%2020%'
# GROUP BY u.UserName
# ORDER BY COUNT(t.Total) DESC
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(9, 'Cornelis', 459.0),
#  (8, 'Erlo', 775.0),
#  (6, 'Zanele', 3464.0),
#  (6, 'Heather', 897.0),
#  (5, 'Mandla', 1351.0),
#  (4, 'lebogang', 386.0),
#  (4, 'Neo', 757.0),
#  (4, 'Melokuhle', 816.0),
#  (4, 'Mel', 1114.0),
#  (4, 'Margaret', 1716.0),
#  (4, 'Lizanie', 540.0),
#  (4, 'Lacin', 30.0),
#  (4, 'Junaid', 3301.0),
#  (4, 'Janet', 757.0),
#  (4, 'Daffy', 1134.0),
#  (4, 'DIMPHO', 1523.0),
#  (4, 'Aqeela', 485.0),
#  (4, 'Anna', 205.0),
#  (3, 'sayidah', 467.0),
#  (3, 'Zelda', 687.0),
#  (3, 'Willard', 617.0),
#  (3, 'Michael', 550.0),
#  (3, 'Melandi', 2535.0),
#  (3, 'Karyn', 1137.0),
#  (3, 'Janine', 259.0),
#  (3, 'Hugo', 794.0),
#  (3, 'Hanno', 1334.0),
#  (3, 'GRANT', 802.0),
#  (3, 'Dino', 524.0),
#  (3, 'Cindy', 1999.0),
#  (3, 'Chelsea', 389.0),
#  (3, 'Brigette', 225.0),
#  (3, 'Ashleigh', 607.0),
#  (3, 'Andrew', 126.0),
#  (3, 'Andreas Peter', 329.0),
#  (3, 'Adele', 1177.0),
#  (2, 'shamil', 52.0),
#  (2, 'keith', 745.0),
#  (2, 'Therry', 175.0),
#  (2, 'Sheila', 44.0),
#  (2, 'S', 692.0),
#  (2, 'Ridhaa', 1.0),
#  (2, 'Nico', 357.0),
#  (2, 'Maryam', 400.0),
#  (2, 'Jakobus', 609.0),
#  (2, 'Hesta', 638.0),
#  (2, 'Hein', 328.0),
#  (2, 'Gert', 504.0),
#  (2, 'Annamarie', 468.0),
#  (1, 'kelly', 150.0),
#  (1, 'justin', 400.0),
#  (1, 'elismary', 79.0),
#  (1, 'dilshad', 420.0),
#  (1, 'cordelia', 115.0),
#  (1, 'chantelle', 175.0),
#  (1, 'berthel', 135.0),
#  (1, 'William', 245.0),
#  (1, 'Wilfred Nkosinathi', 199.0),
#  (1, 'Wendy', 145.0),
#  (1, 'Wayne', 23.0),
#  (1, 'Waylenn', 899.0),
#  (1, 'Vincent', 999.0),
#  (1, 'Vanessa', 39.0),
#  (1, 'Tuwani', 78.0),
#  (1, 'Tshepo', 319.0),
#  (1, 'Trevor', 170.0),
#  (1, 'Todani', 2299.0),
#  (1, 'Tinus', 450.0),
#  (1, 'Timothy', 139.0),
#  (1, 'Theo', 249.0),
#  (1, 'Thabiso', 79.0),
#  (1, 'Tammy', 539.0),
#  (1, 'Sue', 169.0),
#  (1, 'Stephan', 126.0),
#  (1, 'Siphesihle', 99.0),
#  (1, 'Shameer', 126.0),
#  (1, 'Scotty', 29.0),
#  (1, 'Sasha', 149.0),
#  (1, 'SanÃ©', 249.0),
#  (1, 'Sandra', 44.0),
#  (1, 'SEBINA', 219.0),
#  (1, 'Rumbidzayi', 135.0),
#  (1, 'Rozelle', 54.0),
#  (1, 'Rolf', 420.0),
#  (1, 'Riaan', 39.0),
#  (1, 'Reo', 249.0),
#  (1, 'Philip', 66.0),
#  (1, 'Paul', 50.0),
#  (1, 'Patricia', 46.0),
#  (1, 'Nompumelelo', 179.0),
#  (1, 'Nomfanelo', 45.0),
#  (1, 'Nokuthula', 55.0),
#  (1, 'Nicole', 350.0),
#  (1, 'Nick', 23.0),
#  (1, 'Neville', 99.0),
#  (1, 'Nenette', 325.0),
#  (1, 'Mzoxolo', 3765.0),
#  (1, 'Monique', 499.0),
#  (1, 'Michelle', 10.0),
#  (1, 'Marius', 74.0),
#  (1, 'Marco', 145.0),
#  (1, 'Madelein', 110.0),
#  (1, 'Lyle', 81.0),
#  (1, 'Lutendo', 39.0),
#  (1, 'Lizzy', 299.0),
#  (1, 'Lizelle', 629.0),
#  (1, 'Leonard', 899.0),
#  (1, 'Lelethu', 149.0),
#  (1, 'Leigh', 459.0),
#  (1, 'Leandre', 325.0),
#  (1, 'Lauriaan', 49.0),
#  (1, 'Laura', 195.0),
#  (1, 'Khosi', 119.0),
#  (1, 'Keneilwe', 107.0),
#  (1, 'Kelsey Brynne', 798.0),
#  (1, 'Karabo', 250.0),
#  (1, 'Julie Martina', 34.0),
#  (1, 'Johann', 124.0),
#  (1, 'Johan', 349.0),
#  (1, 'Jessica', 75.0),
#  (1, 'Jeandre', 179.0),
#  (1, 'Janice', 198.0),
#  (1, 'Jana', 195.0),
#  (1, 'Jan-Hendrik', 35.0),
#  (1, 'Jaco', 139.0),
#  (1, 'JOHAN', 75.0),
#  (1, 'Ian', 149.0),
#  (1, 'Hester', 189.0),
#  (1, 'Hendrik', 149.0),
#  (1, 'Gerhard', 239.0),
#  (1, 'George', 349.0),
#  (1, 'Freddie', 249.0),
#  (1, 'Faristha', 99.0),
#  (1, 'Eugene', 94.0),
#  (1, 'Enid', 49.0),
#  (1, 'Emily', 107.0),
#  (1, 'Elize', 398.0),
#  (1, 'Eathon', 53.0),
#  (1, 'Dmitri', 279.0),
#  (1, 'Dimitri', 88.0),
#  (1, 'Dawn', 39.0),
#  (1, 'Cornell', 99.0),
#  (1, 'Conrad', 93.0),
#  (1, 'Clodeane', 815.0),
#  (1, 'Claire', 275.0),
#  (1, 'Chaylem', 238.0),
#  (1, 'Charlene', 149.0),
#  (1, 'Casey', 39.0),
#  (1, 'Carel', 799.0),
#  (1, 'Boitumelo', 135.0),
#  (1, 'Bianca', 299.0),
#  (1, 'Beryl', 329.0),
#  (1, 'Anonymous', 1999.0),
#  (1, 'Anita', 170.0),
#  (1, 'Andiswa', 50.0),
#  (1, 'Andisa Moleboheng', 599.0),
#  (1, 'Alicia', 223.0),
#  (1, 'Adeebah', 229.0)]

# %% [markdown]
# Q8) What would the total price be if I had the following items in my cart?
#
# * Estee Lauder Double Wear Stay In Place Makeup
# * Angelcare - Nappy Bin Refill - 3 Pack
# * RCT 650VA Line Interactive UPS

# %%
# %%sql
#
# SELECT SUM (DISTINCT Price)
# FROM Products_3NF
# WHERE ProductDescription ='Estee Lauder Double Wear Stay In Place Makeup'
# OR ProductDescription= 'Angelcare - Nappy Bin Refill - 3 Pack'
# OR ProductDescription='RCT 650VA Line Interactive UPS'
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(1599.0,)]

# %% [markdown]
# Q9) From a stock count point of view, which product in Bhejane has the highest quantity?

# %%
# %%sql
#
# SELECT ProductDescription,Quantity
# FROM Products_3NF
# ORDER BY Quantity DESC
# LIMIT 10;
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('Beard Growth Essential Oil', 500),
#  ('Beard Growth Essential Oil', 500),
#  ('WD Elements Portable 1TB USB 3,0', 499),
#  ('WD Elements Portable 1TB USB 3,0', 499),
#  ('WD Elements Portable 1TB USB 3,0', 499),
#  ('WD Elements Portable 1TB USB 3,0', 499),
#  ('Home Quip USB Rechargeable Emergency Lantern - 500 Lumen', 499),
#  ('Home Quip USB Rechargeable Emergency Lantern - 500 Lumen', 499),
#  ('Home Quip USB Rechargeable Emergency Lantern - 500 Lumen', 499),
#  ('Home Quip USB Rechargeable Emergency Lantern - 500 Lumen', 499)]

# %% [markdown]
# Q10) How many products are imported from the United Kingdom?

# %%
# %%sql
#
# SELECT COUNT(p.ProductDescription) AS imports
# FROM Products_3NF AS p
# JOIN Locations_3NF AS l ON l.LocationID=p.LocationID
# WHERE l.LocationID =2
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(4,)]

# %% [markdown]
# Q11) What is the name and colour of the following item (Barcode TAL00035388021)?

# %%
# %%sql
#
# SELECT p.ProductDescription,c.Colour
# FROM Products_3NF AS p
# JOIN Colours_3NF AS c ON c.ColourID=p.ColourID
# WHERE p.Barcode='TAL00035388021'
# GROUP BY c.Colour
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('Angelcare - Nappy Bin Refill - 3 Pack', 'Blue')]

# %% [markdown]
# Q12) How many beer brands exist in the database?

# %%
# %%sql
# SELECT COUNT(b.Brand)
# FROM Brands_3NF AS b
# JOIN Products_3NF AS p ON p.BrandID=b.BrandID
# WHERE p.ProductDescription LIKE '%beer%'
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(10,)]

# %% [markdown]
# Q13) Which product contains the most package contents and belongs to more than 2 navigation paths?

# %%
# %%sql
#
# SELECT p.ProductDescription,COUNT(n.NavigationPath),COUNT(DISTINCT pc.ItemID) AS COUNT
# FROM Products_3NF AS p
# JOIN Navigation_3NF AS n ON n.PathID=p.PathID
# JOIN PackageContents_3NF AS pc ON p.ItemID=pc.ItemID
# GROUP BY p.ProductDescription
# ORDER BY COUNT DESC
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('Chukbok 15 Piece Heavy Bottom Stainless Steel Cookware Set', 22, 11),
#  ('Art Set - 66 Piece', 44, 11),
#  ('Mellerware - Biltong King Food Dehydrator', 10, 10),
#  ('Nutribullet - Blender Original 600W - 8 Piece', 16, 8),
#  ('Bennett Read Aerovac Vacuum Cleaner 2,0', 8, 8),
#  ('TP-Link TL-MR6400 Archer MR6400 (300MBPS) 4G LTE Router Sim', 7, 7),
#  ('Russell Hobbs - Combo Breakfast Pack - Silver', 7, 7),
#  ('Ematic AGT419 4K (UltraHD) Quad Core Android TV Box (Google and Netflix Certified)', 7, 7),
#  ('TP-Link 300Mbps Wireless N Router', 6, 6),
#  ('Salton - 1,7 Litre Cordless Glass Kettle', 12, 6),
#  ('Russell Hobbs - 1,7 Litre Glass Kettle', 12, 6),
#  ("Nature's Craft - Essential Oil Favourites Gift Pack 6 x 10ml", 6, 6),
#  ('GoFreeTech Wireless Keyboard & Mouse Combo', 6, 6),
#  ('Ezviz C3W Husky Air 1080p Full HD Outdoor WiFi IP Camera - 2,8mm', 6, 6),
#  ('Berlinger Haus 6 Piece Marble Coated Knife Set', 12, 6),
#  ('Yoco Go Card Machine', 5, 5),
#  ('Verimark - Twista Pull Chopper', 10, 5),
#  ('Super Bright 5m 5050 RGB Waterproof Strip Light', 5, 5),
#  ('JBL T500BT Wireless On-Ear Headphones - Black', 5, 5),
#  ('Huawei B311 S-220 4G LTE / WiFi Router Lite - White', 5, 5),
#  ('Face Mask - Reusable Sponge with 1 Breathing Valve', 5, 5),
#  ('Dell SE2416H 23,8" FHD LED Monitor', 5, 5),
#  ('Canon PIXMA TR4540 A4 4-in-1 Wi-Fi Inkjet Printer', 5, 5),
#  ('Canon PIXMA MG2540S A4 3in1 Multifunction Inkjet Printer', 5, 5),
#  ('Barbie Colour Reveal Doll with 7 Surprises - Blindbox', 5, 5),
#  ('4 Piece Dustpan Cleaning Set', 5, 5),
#  ('i12 TWS Wireless Bluetooth Ear Pods with Charging Box', 8, 4),
#  ('Wifi Extender / Repeater - up to 300mbps', 9, 4),
#  ('WD Elements Portable 1TB USB 3,0', 4, 4),
#  ('Verimark - Flawless Facial Hair Remover', 4, 4),
#  ('Super Bright 5m 3528 RGB Waterproof Strip Light', 4, 4),
#  ('Sport Mask with Exhalation Valves', 4, 4),
#  ('Russell Hobbs - Slow Cooker', 4, 4),
#  ('Ring light 10inch ring light with stand', 4, 4),
#  ('Oximeter Medical Finger Pulse Oximeter - Oxygen Level Monitor', 4, 4),
#  ('Nespresso Caffeluxe Coffee Capsules - Origins Mixed Speciality pack 100', 8, 4),
#  ('Mix Box Expands Mobile Phone Selfie Stick Compatible Mobile Phone GoPro', 4, 4),
#  ('Microlab MS212 Bluetooth Soundbar Speaker - Black', 4, 4),
#  ('Mecer 1000VA Line Interactive UPS (Uninterruptable Power Supply)', 4, 4),
#  ('Eco-friendly EEZIGO Portable Laptop Stand', 4, 4),
#  ('Canon VP-101 (A4 & 4x6") Variety Pack', 4, 4),
#  ('Bright Star Lighting - 10 Watt LED Die Cast Aluminium Flood Light', 4, 4),
#  ('5m Colour Changing RGB LED Strip Light', 8, 4),
#  ('25cm Dimmable LED Ring Light Lamp With 52,5cm Light Stand Light Kit', 4, 4),
#  ('YM101 Fingertip Pulse Oximeter, Modern, Clean and Streamlined Design', 3, 3),
#  ('XR Full Screen Tempered Glass Screen Protector iPhone', 3, 3),
#  ('Verimark - Floorwiz 2in1 Mop', 3, 3),
#  ('TP-LINK TL-WA850RE 300Mbps Wi-Fi Range Extender', 3, 3),
#  ('Sports Face Mask with Exhalation Valves', 3, 3),
#  ('Sonoff Basic Smart Switch', 3, 3),
#  ('Seagate 2,5" Expansion Portable Drive - 1TB', 3, 3),
#  ('Russell Hobbs - 20 Litre Classic Manual Microwave', 9, 3),
#  ('RGB Colourful Gaming Mouse Pad - Extra Large', 3, 3),
#  ('Premium Reusable Face Mask with Exhalation Valves', 3, 3),
#  ('Oximeter Medical Finger Pulse Oxymeter - Oxygen level Monitor', 3, 3),
#  ('Milex - Power Airfryer XXXL', 3, 3),
#  ('Huawei Mobile WiFi E5576 LTE', 3, 3),
#  ('Google Home Mini Smart Speaker - Charcoal (Parallel Import)', 3, 3),
#  ('Dunlop Swingball Set', 6, 3),
#  ('Baobab Virtual Reality Headset', 3, 3),
#  ('Ausdom AW635 1080P Streaming Web Camera - Black', 3, 3),
#  ('We Love Gadgets Vlogging LED Ring Light & Tripod', 2, 2),
#  ('The Secret Fat Burner', 2, 2),
#  ('Tech Geeks Mini Wireless Keyboard with Touch pad for Android TV box, PC,TV', 2, 2),
#  ('Success Formula USB Rechargable Mini Torch with Zoom Function', 2, 2),
#  ('Sparq Active Resistance Loop Band - Set of 5 with Bag', 2, 2),
#  ('SanDisk 32GB Ultra Micro UHS-I SDHC C10', 6, 2),
#  ('SanDisk 32GB Micro UHS-l SDHC C 4 SDSDQM-032G-B35A', 6, 2),
#  ('SanDisk 16GB 10 MB/s Micro UHS-l SDHC C 4 SDSDQM-016G-B35A', 6, 2),
#  ('Russell Hobbs - LED Electric Salt & Pepper Mill Set', 2, 2),
#  ('Russell Hobbs - Blade Coffee Grinder', 4, 2),
#  ('Russell Hobbs - 1750W Stainless Steel 4-Slice Toaster - Silver', 2, 2),
#  ('Russell Hobb - Black LED Electric Salt & Pepper Mill Set', 2, 2),
#  ('Resistance Loop Exercise Bands Set', 2, 2),
#  ('Protective Face Shield', 2, 2),
#  ('Pocket Size Stun Gun Taser - Pink', 2, 2),
#  ('Pilot G-2 0,7 Gel Retractable Pen - Black', 14, 2),
#  ('Pilot G-2 0,5 Fine Nib Gel Retractable Pen - Black', 12, 2),
#  ('Optimizor - Premium Dry Dog Food - 20kg', 4, 2),
#  ('Leisurequip USB Rechargeable Mini Lantern 200 Lumen', 2, 2),
#  ('JBL TUNE 500 Wired On Ear Headphones With Mic - Blue', 2, 2),
#  ('Icon Bluetooth Speaker', 2, 2),
#  ('Home Quip USB Rechargeable Emergency Lantern - 500 Lumen', 4, 2),
#  ('Hikvision 1080P 2MP Turbo HD IR Bullet Camera', 2, 2),
#  ('Happy Hugger Microwaveable Therapy Heater Bag - Blue / Green', 2, 2),
#  ('HP 650 Tri-Colour Ink Cartridge', 2, 2),
#  ('HP 123 Tri-Colour Ink Cartridge', 2, 2),
#  ('HP 123 Black Ink Cartridge', 2, 2),
#  ('Google Chromecast 3rd Gen 2018 Black Parallel Import (OEM Packaging)', 2, 2),
#  ('Face Mask - Reusable Sponge with 1 Breathing Valve - Mikay Health', 2, 2),
#  ('Doubleshock 4 PlayStation 4 Wireless Controller: Generic (PS4)', 2, 2),
#  ('Digitronics Protective Tempered Glass for iPhone 11', 2, 2),
#  ('Digitronics Protective Tempered Glass for Samsung Galaxy A30s / A50s / A50', 2, 2),
#  ('Consol - 352ml Honey jars - 6pk', 2, 2),
#  ('Compatible Samsung & Other Smartphone Charger (Micro USB Cable & Wall Adapt', 2, 2),
#  ('Casa Electronic Glass Bathroom Scale - CEGS01', 4, 2),
#  ('Canon PG-440XL Black Ink Cartridge', 2, 2),
#  ('Canon CL-441XL Tri-Colour Ink Cartridge', 2, 2),
#  ('Brother TN1000 /1000 Compatible Toner', 2, 2),
#  ('Bluetooth i7s tws Headset Mini Earbud with Mic', 2, 2),
#  ('Baobab Deskmates+ USB Keyboard And Mouse Combo - Wired', 2, 2),
#  ('rain 4G SIM - unlimited 4G data from only R479', 1, 1),
#  ('iPhone USB Charging Cable for iPhone 5 & 6 - White (Pack of 2)', 1, 1),
#  ('iPhone USB Charging Cable for iPhone 5 & 6 - White', 1, 1),
#  ('iPhone USB Charging Cable for iPhone 5 & 6 & 7 & 8 & X - White (Pack of 2)', 1, 1),
#  ('iPhone USB Charging Cable for iPhone 5 & 6 & 7 & 8 & X - White', 1, 1),
#  ('ZYS 1,8m Folding Table - White', 1, 1),
#  ('Xtreem Surface Cleaner 5L - Bulk Value Size', 2, 1),
#  ('Xtreem Pine Gel 5kg - Bulk Value Size', 2, 1),
#  ("Xtreem Facial Tissues 200's - Value Pack of 2 Boxes", 1, 1),
#  ('Xtreem Disinfectant Cleaner 5L - Bulk Value Size', 2, 1),
#  ('Xtreem Bleach 5L - Bulk Value Size', 2, 1),
#  ('X-360 Wired Controller Gamepad Compatible with Xbox 360 Game Console and PC', 1, 1),
#  ('Wireless Double Shock Controller for PS3', 1, 1),
#  ('Wireless Bluetooth Receiver 3,5mm Jack Audio Music Adapter', 2, 1),
#  ('Windhoek Draught - Beer - 24 x 440ml', 1, 1),
#  ('Western Digital Green 240Gb 2,5" SATA SSD', 1, 1),
#  ('Weber - 4kg Briquettes - 3 Pack', 2, 1),
#  ('Washable KN95 Dual Valve Sports Mask - Black', 1, 1),
#  ('Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', 5, 1),
#  ('Wahl Easy Cut 15 Piece Complete Hair Clipper Kit', 2, 1),
#  ('WD Blue 1TB 3,5" SATA 6Gb/s 64MB Internal Hard Drive', 1, 1),
#  ('Voyager Portable USB Humidifier', 1, 1),
#  ('Volkano Vector Duo Wireless Mouse - Pack of 2', 1, 1),
#  ('Volkano Race Series Bluetooth Sport Earphones - Black', 1, 1),
#  ('Volkano Lunar Bluetooth Headphones - White & Rose Gold', 1, 1),
#  ('Volkano Falcon Series Headphones with Mic - Black', 1, 1),
#  ('Volkano Comfort Series Gel Wristguard Mousepad', 2, 1),
#  ('Volkano Alloy Series Metal Earphones - Silver', 1, 1),
#  ('Vitamin D3 1000iu - 30 Tablets', 1, 1),
#  ('Vitamin C + Selenium & Zinc Immune Booster - 3 Pack 180 Capsules', 2, 1),
#  ('Victoria Limited Edition Orange Blossom & Rose Hip by Minki - 750ml', 1, 1),
#  ('Verimark - Microwiz Cleantech 10 Pack', 3, 1),
#  ('Varta AAA Longlife Batteries - 6 Pack', 2, 1),
#  ('VacBag - Value Bulk Pack', 2, 1),
#  ('Uric Acid Support - 100ml', 1, 1),
#  ('Unrefined Shea butter 250g', 1, 1),
#  ('USB Type C Data Cable - White', 1, 1),
#  ('UGreen 0,5m USB2,0 Male to Female Extension Cable', 2, 1),
#  ('Typek: A4 White Copy Printer Paper - Ream', 1, 1),
#  ('Typek Box of A4 White Copier Paper', 2, 1),
#  ('Tuff-Luv Ultra Slim Wrist Supporter Mouse Pad - Black', 2, 1),
#  ('Treeline Spiral Note Book Side Bound A4 - Wiro 100pg', 2, 1),
#  ('Treeline Filing Pockets 40 Micron PVC A4 - Pack of 100', 4, 1),
#  ("Toshiba Canvio Basic 1TB 2,5'' External Hard Drive", 1, 1),
#  ('TomTom Watch Strap Runner 2 3/Spark 2 3/Golfer 2/Adventurer', 1, 1),
#  ('Three Ships - Select Whisky - 750ml', 1, 1),
#  ('Think Like a Monk', 1, 1),
#  ('Thermometer Infrared Forehead Non-Contact Handheld Pack of 1 Dikang', 1, 1),
#  ('The Subtle Art of Not Giving a F*ck', 1, 1),
#  ("The Lazy Makoti's guide to the kitchen", 1, 1),
#  ('The Chocolate Block - 750ml', 1, 1),
#  ('The Alchemist', 1, 1),
#  ('The 5 AM Club', 1, 1),
#  ('Teddy Finger Paint', 4, 1),
#  ('TLM Colour Changing Foundation and Moisturiser', 1, 1),
#  ('SwanSoft Toilet Paper 2Ply - 18 Rolls', 1, 1),
#  ('Star Master Night Light - Pink', 1, 1),
#  ('Star Master Night Light - Blue', 1, 1),
#  ('Sports Face Mask with Double Air Valves', 1, 1),
#  ('Sponduct Face Mask - 360 Filter Reusable Washable Respiratory Valve - 1', 1, 1),
#  ('SponDuct 3D Filter-Valve Face Mask', 1, 1),
#  ('Spider Flexible Camera Tripod - Black', 1, 1),
#  ('Sophie Moda-Ice Cooling Microfiber Washable 3D Face Mask(3pcs Black)-KZ1289', 1, 1),
#  ('Sophie Moda Face Mask - Ice Cooling Microfiber Washable 3D (3 Piece) KZ1289', 1, 1),
#  ('Sodastream - Model 60 Boxed Cylinder', 1, 1),
#  ('Sodastream - Classic Carbonating Bottle 1 Litre Twin pack', 2, 1),
#  ('Similac Total Comfort 3 - 820g', 1, 1),
#  ('Similac Total Comfort 1 - 820g', 1, 1),
#  ('ShopCollagen Peptiplus Pure Granulated Collagen Hydroslysate - 200g', 1, 1),
#  ('Shockproof TPU Gel Cover for iPhone 6 and 6S - Clear', 1, 1),
#  ('Shield - Mr Sheen Automatic Dishwasher Detergent Tablets', 1, 1),
#  ('Shield - MicroFibre All Purpose Cloths 10 Pack', 1, 1),
#  ("Shield - Hang 'Em Up Broom & Tool Organiser", 1, 1),
#  ('Schwarzkopf Got2b Guardian Angel Heat Protection 200ml', 1, 1),
#  ('Schwarzkopf Got2b Glued Hairspray 300ml', 1, 1),
#  ('Sandisk Ultra 32GB USB3,0 Dual Flash Drive', 1, 1),
#  ('Sandisk Cruzer Blade 64GB Flash Drive', 1, 1),
#  ('Sandisk Cruzer Blade 16GB - Flash Drive', 1, 1),
#  ('SanDisk Cruzer Blade 16GB USB Flash Drive - Electric Pink', 1, 1),
#  ('SanDisk Cruzer Blade 16GB USB Flash Drive - Electric Green', 1, 1),
#  ('SanDisk Cruzer Blade 16GB USB Flash Drive - Electric Blue', 1, 1),
#  ('SanDisk 64GB 98 MB/s Ultra Micro UHS-l SDXC C10', 3, 1),
#  ('SanDisk 64GB 80 MB/s Ultra SD Card UHS-l SDXC C10', 2, 1),
#  ('SanDisk 16GB 98 MB/s Ultra Micro UHS-l SDHC C10', 3, 1),
#  ('SanDisk 128GB 100 MB/s Ultra Micro UHS-I SDXC C10', 3, 1),
#  ('Samyang Hot Chicken Noodle Original', 1, 1),
#  ('Samyang Hot Chicken Noodle Carbonara', 1, 1),
#  ('Samsung And Other Smartphone Charger (Micro USB Cable And Wall Adapter)', 2, 1),
#  ('Samsung 30Q 18650 3000mah', 1, 1),
#  ('SafeT Face Shield', 1, 1),
#  ('STARBUCKS Single-Origin Colombia by NESPRESSO Medium Roast Coffee', 2, 1),
#  ('STARBUCKS House Blend by NESPRESSO Medium Roast Coffee', 2, 1),
#  ('STARBUCKS Cappuccino by NESCAFE DOLCE GUSTO Coffee', 2, 1),
#  ('Ryobi - Glue Gun In Carry Case - 80W', 1, 1),
#  ('Russell Hobbs - 2000W Sandwich Press - Silver', 1, 1),
#  ('Russell Hobbs - 1,7 Litre Cordless Kettle', 4, 1),
#  ('Romoss Sense 8+ 30000MAH QC Type- C Power Bank - White', 2, 1),
#  ('Richelieu - International Brandy - 750ml', 1, 1),
#  ('Rhodes - Tomato Chopped Peeled 12x400g', 1, 1),
#  ('Reusable Sponge Face Mask with 2 breathing Valves', 1, 1),
#  ('Reusable Filter Vent Face Mask - Pack of 3', 1, 1),
#  ('Reusable Filter Vent Face Mask', 1, 1),
#  ('Reusable Filter Face Mask - Mikay Health', 1, 1),
#  ('Reusable Face Mask with Vent', 1, 1),
#  ("Re-Useable Children's Facial Mask with Panda Filter - Black", 1, 1),
#  ('Rawbiotics Gut 1 Litre', 1, 1),
#  ('Raw African Black Soap 200g', 3, 1),
#  ('RCT 650VA Line Interactive UPS', 1, 1),
#  ('RCT 2000VA Line Interactive UPS', 1, 1),
#  ('Pyrex - Mixing Bowl - 3 Litre', 2, 1),
#  ('Pure Pleasure - Tie-down Electric Blanket - 3/4 Double', 1, 1),
#  ('Pure Pleasure - Non-Fitted Electric Blanket - Single', 1, 1),
#  ('Pure Beginnings - Soothing Baby Wash and Shampoo with Organic Baobab - White', 1, 1),
#  ('Pure Beginnings - Biodegradable Baby Wipes with Organic Aloe - White', 1, 1),
#  ('Pure Beginnings - Baby Bum Cream with Organic Baobab - White', 1, 1),
#  ('Pulse Oxymeter - Fingertip Oxygen Screening Monitor Oximeter', 1, 1),
#  ('Pritt Stick 43g Glue Stick', 6, 1),
#  ('Prepaid Electricity Meter 80Amp', 1, 1),
#  ('Premium Wood Pellet Cat Litter / 100% Natural 15Kgs', 1, 1),
#  ('Police Type Self-Defensive LED Torch + Stun Gun', 1, 1),
#  ('Pigeon - Breast Pads - Honeycomb', 1, 1),
#  ('Philips - Steam Iron - Green', 2, 1),
#  ('Philips - Descaling Cycle Espresso Machine Descaler - Silver', 3, 1),
#  ('Peppa Pig: Bedtime Little Library', 1, 1),
#  ('Pediasure Complete Vanilla - 850g', 1, 1),
#  ('Parrot Products Eraser Whiteboard (95*50mm 12 Peel Off Layers)', 4, 1),
#  ('Pampers Sensitive Baby Wipes - 9 x 56 - 504 Wipes', 1, 1),
#  ('Pampers Sensitive Baby Wipes - 6 x 56 - 336 Wipes', 1, 1),
#  ('Pampers Sensitive Baby Wipes - 4 x 56 - 224 Wipes', 1, 1),
#  ('Pampers Premium Care - Size 5 Mega Pack - 88 Nappies', 1, 1),
#  ('Pampers Premium Care - Size 1 Carry Pack - 22 Nappies', 1, 1),
#  ('Pampers Pants - Size 6 Mega Box - 96 Nappies', 1, 1),
#  ('Pampers Pants - Size 5 Mega Box - 100 Nappies', 1, 1),
#  ('Pampers Complete Clean Bulk Wipes - 12 x 64 - 768 Wipes - Bulk Pack', 1, 1),
#  ('Pampers Complete Clean Baby Wipes - 6 x 64 - 384 Wipes', 1, 1),
#  ('Pampers Baby Dry - Size 5 Mega Pack - 111 Nappies', 2, 1),
#  ('PS4 Dualshock 4 Controller - Black V2 (PS4)', 1, 1),
#  ('PPE Face Shield', 1, 1),
#  ('PAMPERS NEW BABY-DRY SIZE 1 NEW BORN 27 PER PACK', 2, 1),
#  ('Outback Pain Relief Roll-On - 50ml', 1, 1),
#  ('Oral-B Rechargeable Electric Toothbrush - Vitality Precision Clean', 1, 1),
#  ('Optimizor - Complete Dog Food - Adult - 20kg', 2, 1),
#  ('Omniprotect Aerosol Sanitiser 120ml - 70% Alcohol', 1, 1),
#  ('Old El Paso - 12 Crunchy Taco Shells 156g', 1, 1),
#  ('Okja Oat Milk 1 Litre x 12 units', 1, 1),
#  ('Neutriherbs Retinol Serum For Face (30ml)', 1, 1),
#  ('Neutriherbs Hyaluronic Acid Serum With Vitamin C (30ml)', 1, 1),
#  ('Neutriherbs Enhanced Vitamin C Serum with Hyaluronic Acid (30ml)', 1, 1),
#  ('Nestle - Nido 1+ - 1,8kg', 2, 1),
#  ('Nescafe Gold - Cappuccino Unsweetened - 10 x 12,5g Sachets', 2, 1),
#  ('NeoVita Daily Women\\92s Multivitamin Gummies 60', 1, 1),
#  ("Nature's Craft Pure Eucalyptus Essential Oil 10ml", 1, 1),
#  ("Nature's Craft 8 Pack Essential Oils - 8 x 10ml", 1, 1),
#  ('Nano Wave Mask Adult Black', 1, 1),
#  ('Multiple-mode LED Ring Light On Tripod', 2, 1),
#  ('Mpesu Venda Libido Booster Capsules', 1, 1),
#  ('Moto-Quip - Mag Wheel Cleaning Brush', 2, 1),
#  ('Motherkind Collagen - Glow From Within 250g', 2, 1),
#  ('Montego - Monty & Me Essential 20kg', 1, 1),
#  ('Montego - Classic Wet Puppy Chicken - 380g', 1, 1),
#  ('Montego - Classic Wet Adult Chicken - 770g', 1, 1),
#  ('Montego - Classic Adult Dog Succulent Beef & Wholesome Veggies - 385g', 1, 1),
#  ("Montego - Bags O' Wags Peanut Butter Crunchies 1kg", 1, 1),
#  ('Mondi Rotatrim Box of A4 Paper', 2, 1),
#  ('Mix Box Large XL Size Anti-Slip World Map Speed Game Mouse Pad Gaming Mat for Laptop PC', 1, 1),
#  ('Mini 2,4GHz Wireless Keyboard Touchpad Mouse with backlight', 2, 1),
#  ('Minhaj - 1,8m Folding Trestle Table', 1, 1),
#  ('Milo Duo Cereal 400g', 1, 1),
#  ('Microsoft Wireless Mobile Mouse 1850 - Black', 2, 1),
#  ('Metalix Tin Standard Baking Tray', 1, 1),
#  ('Metalix 12 Cup Tin Mini Muffin Pan', 1, 1),
#  ('Memre - Air Foam Premium Classic Pillow', 1, 1),
#  ('Memre - Air Foam Contour Pillow', 1, 1),
#  ('Mellerware - Dopio Sandwich Toaster - Black', 1, 1),
#  ('Megamaster Two Pack Lighters', 2, 1),
#  ('Medical Protective Mask- N95 FFP2', 1, 1),
#  ('Medic Powder-Free Disposable Latex Gloves - Pack of 100 - Medium', 1, 1),
#  ('Marco Mousepad with Gel Wrist Support', 3, 1),
#  ('Marble - Triple Layer - Fabric Face Mask - Pack of 4', 1, 1),
#  ('Manage your money like a f*cking grown up', 1, 1),
#  ('Lightning to Headphone Jack Adapter for iPhone', 1, 1),
#  ('Leopard 4-Tier Chrome Plated Storage Rack', 4, 1),
#  ('Leisure-quip Non Toxic Flat Easy Pack Ice Brick - Blue - 400ml', 1, 1),
#  ('Lasa 500g/0,01g Digital Pocket Scale', 2, 1),
#  ('LDNIO Micro USB Charge Cable for Android Phones - Dual Pack', 1, 1),
#  ('LDNIO Dual USB Travel Wall Charger Power Adapter (A2202)', 2, 1),
#  ('LDNIO 1m Fast Charging & Data USB Cable for iOS (Pack of 2)', 1, 1),
#  ('Klipdrift - Export Brandy - 750ml', 1, 1),
#  ('Kids Turtles & Dinosaurs - Triple Layer - Fabric Face Mask - Pack of 4', 1, 1),
#  ('KetoVatru', 1, 1),
#  ('Kenwood - Hand Mixer - HM330', 2, 1),
#  ('KOO - Baked Beans in Tomato Sauce 4x410g', 1, 1),
#  ('KN95 Respiratory Protection Face Mask - 20 x KN95', 1, 1),
#  ('KN95 Dual Breathing Face Mask', 1, 1),
#  ('KN95 Disposable Mask Box of 20', 1, 1),
#  ('Johnsons, Wipes, Gentle All Over Wipes, Pack Of 432 Wipes', 1, 1),
#  ('Jameson - Irish Whiskey - 750ml', 1, 1),
#  ('J&B - Rare Scotch Whisky - 750ml', 1, 1),
#  ('Iphone Replica Headset With Remote & Mic For Iphone And Other Smartphones', 1, 1),
#  ('Immunadue 100 Capsules Multi-Vitamin, Mineral and Immune Modulator', 2, 1),
#  ('Hyaluronic Acid Serum', 1, 1),
#  ('House of York - Slotted Wooden Spoon', 2, 1),
#  ('House of York - Slotted Wooden Spatula', 1, 1),
#  ('House Of Hamilton Standard Twin Pack Pillows', 1, 1),
#  ('Home-Quip Flexlite - USB Rechargeable flexible desk light - Black', 2, 1),
#  ('Home Classix - Melamine Dessert Bowl - 15cm', 1, 1),
#  ('Heineken 0,0 24 x 330ml NRB Beer', 2, 1),
#  ('HTH - Floater+ for Large Pools - 1,6kg', 1, 1),
#  ('HP: A4 Everyday Paper - White Copy Printer Paper - Box', 2, 1),
#  ('HP 650 Black Ink Cartridge', 1, 1),
#  ('HDMi Cable Braided 3m - Black & Red', 1, 1),
#  ('HDMI To VGA Adaptor Cable', 1, 1),
#  ('HDMI To VGA Adaptor', 3, 1),
#  ('HDMI 5m Braided Cable', 1, 1),
#  ('HDMI 10m Braided Cable', 1, 1),
#  ('GoFreetech Wireless Mouse 1600DPI', 2, 1),
#  ('GoFreeTech GFT-M001 Wireless Optical Mouse - Black', 2, 1),
#  ('Glenfiddich - 12 Year Old Special Reserve Single Malt Whisky - 750ml', 1, 1),
#  ('Gizmo - Pegs - Pack Of 50', 2, 1),
#  ('Gizmo - Junior Hangers - Set Of 5 - White', 1, 1),
#  ('Gizmo - Hangers - Set Of 10', 1, 1),
#  ('Gizmo - 30cm Microwave Cover', 2, 1),
#  ('Full Face Shield Protective Face Mask With Forehead Cushion x 5pack', 1, 1),
#  ('Full Curved Tempered Glass for Huawei P30 lite', 1, 1),
#  ('Finish Auto Dishwashing Rinse Aid Lemon - 400ml', 2, 1),
#  ('Finish Auto Dishwashing Machine Cleaner - 250ml', 2, 1),
#  ("Finish Auto Dishwashing All in One Tablets Regular - 100's", 1, 1),
#  ('Fine Living - 1,8m Folding Table - White', 1, 1),
#  ('Fellowes HFC Free Air Duster - 350ml', 1, 1),
#  ('Feline Cuisine - Adult Chicken & Rice - 4kg', 1, 1),
#  ('Fast-Feet Skipping Rope', 1, 1),
#  ('FaceMask - High Efficiency Disposable CE Face Masks - 50 Pack', 3, 1),
#  ('Face Mask - Reusable Sponge with 2 Breathing Valves', 1, 1),
#  ('Face Mask - Reusable Sponge with 1 Breathing Valve x 2', 1, 1),
#  ('Face Mask - Reusable Sponge with 1 Breathing Valve (5 pack) - Mikay Health', 1, 1),
#  ('Face Mask - Kids Pink Reusable Sponge with Panda Valve', 1, 1),
#  ('Face Mask - Disposable 3-Ply (50 Per Box)', 1, 1),
#  ('Face Mask - 3 x Reusable Masks with Vent', 1, 1),
#  ('Face Mask - 3 Ply Surgical (Pack of 20)', 1, 1),
#  ('Eveready AAA Power Plus Batteries - Black & Silver', 1, 1),
#  ('EverFresh Full Cream Long Life Milk 6 x 1Lt', 1, 1),
#  ('Energizer Miniature Aaaa: E96 (2 Pack)', 2, 1),
#  ('Energizer CR2032 Lithium Coin Battery - 3V', 3, 1),
#  ('Energizer AAA 700Mah Rechargeable Batteries', 2, 1),
#  ('Energizer AA 2300Mah Rechargeable batteries', 2, 1),
#  ('Ellies Wonder Surge Adaptor', 2, 1),
#  ('Ellies High Speed HDMI Cable - 1,5m', 1, 1),
#  ('Earbud Earphones H5 - White', 2, 1),
#  ('Durag King - Durag - Spandex - Black', 1, 1),
#  ('Duracell Rechargeable AAA 900mAh Batteries - 4 Pack', 1, 1),
#  ('Duracell Rechargeable AA 2500mAh Batteries - 4 Pack', 1, 1),
#  ('Duracell Plus Alkaline AAA Batteries - 20 Pack', 1, 1),
#  ('Duracell Plus Alkaline AA Batteries - 20 Pack', 1, 1),
#  ('Duracell 2032 Speciality 3V Lithium Coin Batteries', 1, 1),
#  ('Dock/Stand for Apple Watch & iPhone', 2, 1),
#  ('Disposable Medical Face Mask', 1, 1),
#  ('Disposable 3 Ply Masks - (50 masks in a box)', 1, 1),
#  ('Discovery Reusable Fabric Face Mask for Kids - Pack of 4', 1, 1),
#  ('Discovery Reusable Fabric Face Mask for Kids - Green - Junior', 1, 1),
#  ('Discovery Face Mask - Reusable Fabric (Pack of 4)', 1, 1),
#  ("Dinu Bathroom Tissue 2 ply White Rose 18's 350 sheets", 2, 1),
#  ('Digitronics Protective Shockproof Gel Case for iPhone 11', 1, 1),
#  ('Digital Temperature & Humidity Thermometer Indoor Clock', 1, 1),
#  ('Digital Stainless Cooking Thermometer', 1, 1),
#  ('Digital Infrared Thermometer', 1, 1),
#  ("Devil's Peak Hero - Non-Alcoholic Beer", 2, 1),
#  ('Dettol Hygiene Kitchen Trigger - Lemon Zest - 6 x 500ml', 2, 1),
#  ('Dettol Body Wash - Shower Gel - Original - 600ml', 1, 1),
#  ('Delonghi - Double Wall Thermo Latte Glasses', 1, 1),
#  ('D-Link DWM-222 4G LTE USB Adapter', 1, 1),
#  ('Croxley Create Fine Nib Whiteboard Markers - Blister of 10', 11, 1),
#  ('Compatible Canon 737 Black Laser Toner Cartridge', 1, 1),
#  ('Coffee Wholesalers Roasters - 1kg Brazil Medium Dark Roast Beans', 1, 1),
#  ('Charging Station PS4 Playstation Dual Shock Controller', 1, 1),
#  ('Charging Cable for Iphone 6 /7 /7 Plus/8 & 8 Plus', 1, 1),
#  ('Catmor - Dry Cat Food - Chicken - 4kg', 2, 1),
#  ('Castle Lite Beer 24 x 340ml', 1, 1),
#  ('Castle Free Non-Alcholic Beer 24 x 500ml', 2, 1),
#  ('Castle Free Non-Alcholic Beer 24 x 340ml', 2, 1),
#  ('Casa - Glass Kitchen Scale - Nero', 1, 1),
#  ('Casa - Catania 201 2 Tier Dish Drainer', 1, 1),
#  ('Canon PG-445XL Black Ink Cartridge', 1, 1),
#  ('Canon PG-445 & CL-446 Ink Cartridges Multipack', 1, 1),
#  ('Canon Cartridge PG 445 Black', 1, 1),
#  ('Camo - Triple Layer - Fabric Face Mask - Pack of 4', 1, 1),
#  ('Caffenu - Liquid Eco Descaler', 3, 1),
#  ('Cadac Gas Cylinder - 5kg', 2, 1),
#  ('Cadac - 9KG Gas Cylinder - Blue', 1, 1),
#  ('Cadac - 220GR Nozzle Valve Cartridge', 1, 1),
#  ('CANON 446XL HIGH YIELD TRI-colour INK CARTRIDGE', 2, 1),
#  ('Buffelsfontein - Brandy - 750ml', 1, 1),
#  ('Bootlegger Coffee Capsule Sleeve - 10 Capsules', 1, 1),
#  ('Bombay Dry Gin ', 1, 1),
#  ('Body Glove Tempered Glass Screenguard Apple iPhone 11/XR', 1, 1),
#  ('Black - Triple Layer - Fabric Face Mask - Pack of 4', 1, 1),
#  ('Bennett Read Vacuum Sealer Replacement Rolls', 1, 1),
#  ('Bennett Read Vacuum Sealer', 1, 1),
#  ('Bennet Read - Magneto LED Lantern - 2,0', 2, 1),
#  ('Beare Surgical Face Mask - 3-Ply (Pack of 50)', 1, 1),
#  ('Beard Growth Essential Oil', 2, 1),
#  ('Baobab HDMI V1,4B Cable Black - 1,5M', 1, 1),
#  ('Arnotts - Tim Tam Double Coat Chocolate Biscuits 200g', 1, 1),
#  ('Arnotts - Tim Tam Chocolate Biscuits 200g', 1, 1),
#  ('Angelcare - Nappy Bin Refill - 3 Pack', 2, 1),
#  ('Amplify New Revolutionary Earphones - Black/Red', 1, 1),
#  ('Alva - Single Burner Canister Stove', 3, 1),
#  ('Alva - Gas Level Indicator', 1, 1),
#  ('Alva - 220G Butane Canister', 2, 1),
#  ('Aluminium Fold Away Wash Line', 1, 1),
#  ('Adjustable Hook & Loop Waist Trainer Belt - Black', 1, 1),
#  ('Addis - 110 Litre Rough Tote - Black', 1, 1),
#  ('Adata 20 000 Mah Power Bank - Black', 2, 1),
#  ('Adaptive Fast Charger Micro USB Cable for Smartphones', 2, 1),
#  ('70% Alcohol Hand Sanitizer 5L', 1, 1),
#  ('7 Ports USB 2,0 HUB - High Speed USB HUB - Black', 2, 1),
#  ("6 Way Multi - Plug with 2 USB's", 1, 1),
#  ('3 Way Adaptor With Usb Charger', 1, 1),
#  ('10m Extension Cord With A Two-Way Multi-Plug Extension Lead', 1, 1),
#  ('100% Cotton Face Mask - Multi- Coloured Pack of 5', 3, 1),
#  ('100% Cotton 3-ply Face Mask - White', 3, 1),
#  ('100% Cotton 3-ply Face Mask - Navy', 3, 1),
#  ('10 Piece Marble Style Professional Makeup Brush Cosmetic Set - Black', 1, 1),
#  ('1 X HURACAN Nanowave Reusable Mask with Respirator', 1, 1)]

# %% [markdown]
# Q14) Which user bought the product: "Canon PG-445 & CL-446 Ink Cartridges Multipack" in the month of May 2020 and what is their warranty type?

# %%
# %%sql
#
# SELECT u.UserName,pc.Warranty,t.InvoiceDate
# FROM Users_3NF AS u
# JOIN Transactions_3NF AS t ON t.UserID=u.UserID
# JOIN Products_3NF AS p ON p.Barcode=t.Barcode
# JOIN PackageContents_3NF AS pc ON pc.ItemID=p.ItemID
# WHERE p.ProductDescription='Canon PG-445 & CL-446 Ink Cartidges Multipack'
# GROUP BY u.UserName,pc.Warranty
# Out:
#  * sqlite:///bhejane.db
# Done.
# []

# %% [markdown]
# Q15) Which user(s) bought silver coloured products from the Russell Hobbs brand?

# %%
# %%sql
#
# SELECT u.UserName,b.Brand,c.Colour,p.ProductDescription
# FROM Users_3NF AS u
# JOIN Transactions_3NF AS t ON t.UserID=u.UserID
# JOIN Products_3NF AS p ON p.Barcode=t.Barcode
# JOIN Brands_3NF AS b ON b.BrandID=p.BrandID
# JOIN Colours_3NF AS c ON c.ColourID=p.ColourID
# WHERE b.Brand='Russell Hobbs'
# AND c.Colour='Silver'
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('Karyn', 'Russell Hobbs', 'Silver', 'Russell Hobbs - 2000W Sandwich Press - Silver'),
#  ('Clodeane', 'Russell Hobbs', 'Silver', 'Russell Hobbs - 1750W Stainless Steel 4-Slice Toaster - Silver'),
#  ('Clodeane', 'Russell Hobbs', 'Silver', 'Russell Hobbs - 1750W Stainless Steel 4-Slice Toaster - Silver')]
